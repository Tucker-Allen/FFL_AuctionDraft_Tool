# %% [markdown]
# FYI, 210 will be drafted (14 * 15)

# %% [markdown]
# ### Fantasy Pros

# %%
with open('./fantasypros_values.txt') as f:
    lines = f.readlines()

# %%
lines[0].split('\t')
# Out:
# ['#', 'QB', 'Value\n']

# %%
fpros_players = {}
for line in lines:
    sep = line.split('\t')
    if sep[1] in ['QB', 'RB', 'WR', 'DST', 'TE', 'K']:
        pos = sep[1]
        continue
    fpros_players[ sep[1] ] = {'name': sep[1],
                              'position': pos,
                              'fpros_pre_draft$': sep[2].strip()}

# %%
fpros_players
# Out:
# {'Patrick Mahomes, KC': {'name': 'Patrick Mahomes, KC',
#   'position': 'QB',
#   'fpros_pre_draft$': '$31'},
#  'Deshaun Watson, HOU': {'name': 'Deshaun Watson, HOU',
#   'position': 'QB',
#   'fpros_pre_draft$': '$22'},
#  'Aaron Rodgers, GB': {'name': 'Aaron Rodgers, GB',
#   'position': 'QB',
#   'fpros_pre_draft$': '$18'},
#  'Matt Ryan, ATL': {'name': 'Matt Ryan, ATL',
#   'position': 'QB',
#   'fpros_pre_draft$': '$16'},
#  'Cam Newton, CAR': {'name': 'Cam Newton, CAR',
#   'position': 'QB',
#   'fpros_pre_draft$': '$14'},
#  'Andrew Luck, IND': {'name': 'Andrew Luck, IND',
#   'position': 'QB',
#   'fpros_pre_draft$': '$12'},
#  'Drew Brees, NO': {'name': 'Drew Brees, NO',
#   'position': 'QB',
#   'fpros_pre_draft$': '$11'},
#  'Jameis Winston, TB': {'name': 'Jameis Winston, TB',
#   'position': 'QB',
#   'fpros_pre_draft$': '$10'},
#  'Dak Prescott, DAL': {'name': 'Dak Prescott, DAL',
#   'position': 'QB',
#   'fpros_pre_draft$': '$10'},
#  'Carson Wentz, PHI': {'name': 'Carson Wentz, PHI',
#   'position': 'QB',
#   'fpros_pre_draft$': '$10'},
#  'Baker Mayfield, CLE': {'name': 'Baker Mayfield, CLE',
#   'position': 'QB',
#   'fpros_pre_draft$': '$10'},
#  'Jared Goff, LAR': {'name': 'Jared Goff, LAR',
#   'position': 'QB',
#   'fpros_pre_draft$': '$9'},
#  'Ben Roethlisberger, PIT': {'name': 'Ben Roethlisberger, PIT',
#   'position': 'QB',
#   'fpros_pre_draft$': '$9'},
#  'Lamar Jackson, BAL': {'name': 'Lamar Jackson, BAL',
#   'position': 'QB',
#   'fpros_pre_draft$': '$7'},
#  'Russell Wilson, SEA': {'name': 'Russell Wilson, SEA',
#   'position': 'QB',
#   'fpros_pre_draft$': '$7'},
#  'Tom Brady, NE': {'name': 'Tom Brady, NE',
#   'position': 'QB',
#   'fpros_pre_draft$': '$7'},
#  'Kirk Cousins, MIN': {'name': 'Kirk Cousins, MIN',
#   'position': 'QB',
#   'fpros_pre_draft$': '$6'},
#  'Mitch Trubisky, CHI': {'name': 'Mitch Trubisky, CHI',
#   'position': 'QB',
#   'fpros_pre_draft$': '$6'},
#  'Philip Rivers, LAC': {'name': 'Philip Rivers, LAC',
#   'position': 'QB',
#   'fpros_pre_draft$': '$5'},
#  'Kyler Murray, ARI': {'name': 'Kyler Murray, ARI',
#   'position': 'QB',
#   'fpros_pre_draft$': '$4'},
#  'Josh Allen, BUF': {'name': 'Josh Allen, BUF',
#   'position': 'QB',
#   'fpros_pre_draft$': '$2'},
#  'Jimmy Garoppolo, SF': {'name': 'Jimmy Garoppolo, SF',
#   'position': 'QB',
#   'fpros_pre_draft$': '$1'},
#  'Derek Carr, OAK': {'name': 'Derek Carr, OAK',
#   'position': 'QB',
#   'fpros_pre_draft$': '$0'},
#  'Matthew Stafford, DET': {'name': 'Matthew Stafford, DET',
#   'position': 'QB',
#   'fpros_pre_draft$': '$0'},
#  'Andy Dalton, CIN': {'name': 'Andy Dalton, CIN',
#   'position': 'QB',
#   'fpros_pre_draft$': '$0'},
#  'Sam Darnold, NYJ': {'name': 'Sam Darnold, NYJ',
#   'position': 'QB',
#   'fpros_pre_draft$': '$0'},
#  'Marcus Mariota, TEN': {'name': 'Marcus Mariota, TEN',
#   'position': 'QB',
#   'fpros_pre_draft$': '$0'},
#  'Nick Foles, JAC': {'name': 'Nick Foles, JAC',
#   'position': 'QB',
#   'fpros_pre_draft$': '$0'},
#  'Joe Flacco, DEN': {'name': 'Joe Flacco, DEN',
#   'position': 'QB',
#   'fpros_pre_draft$': '$0'},
#  'Eli Manning, NYG': {'name': 'Eli Manning, NYG',
#   'position': 'QB',
#   'fpros_pre_draft$': '$0'},
#  'Ryan Fitzpatrick, MIA': {'name': 'Ryan Fitzpatrick, MIA',
#   'position': 'QB',
#   'fpros_pre_draft$': '$0'},
#  'Dwayne Haskins, WAS': {'name': 'Dwayne Haskins, WAS',
#   'position': 'QB',
#   'fpros_pre_draft$': '$0'},
#  'Chicago Bears': {'name': 'Chicago Bears',
#   'position': 'DST',
#   'fpros_pre_draft$': '$2'},
#  'Los Angeles Rams': {'name': 'Los Angeles Rams',
#   'position': 'DST',
#   'fpros_pre_draft$': '$2'},
#  'New Orleans Saints': {'name': 'New Orleans Saints',
#   'position': 'DST',
#   'fpros_pre_draft$': '$1'},
#  'Baltimore Ravens': {'name': 'Baltimore Ravens',
#   'position': 'DST',
#   'fpros_pre_draft$': '$1'},
#  'Cleveland Browns': {'name': 'Cleveland Browns',
#   'position': 'DST',
#   'fpros_pre_draft$': '$1'},
#  'Minnesota Vikings': {'name': 'Minnesota Vikings',
#   'position': 'DST',
#   'fpros_pre_draft$': '$1'},
#  'Indianapolis Colts': {'name': 'Indianapolis Colts',
#   'position': 'DST',
#   'fpros_pre_draft$': '$1'},
#  'Pittsburgh Steelers': {'name': 'Pittsburgh Steelers',
#   'position': 'DST',
#   'fpros_pre_draft$': '$1'},
#  'Philadelphia Eagles': {'name': 'Philadelphia Eagles',
#   'position': 'DST',
#   'fpros_pre_draft$': '$1'},
#  'Los Angeles Chargers': {'name': 'Los Angeles Chargers',
#   'position': 'DST',
#   'fpros_pre_draft$': '$1'},
#  'Buffalo Bills': {'name': 'Buffalo Bills',
#   'position': 'DST',
#   'fpros_pre_draft$': '$1'},
#  'Denver Broncos': {'name': 'Denver Broncos',
#   'position': 'DST',
#   'fpros_pre_draft$': '$1'},
#  'Houston Texans': {'name': 'Houston Texans',
#   'position': 'DST',
#   'fpros_pre_draft$': '$1'},
#  'New England Patriots': {'name': 'New England Patriots',
#   'position': 'DST',
#   'fpros_pre_draft$': '$1'},
#  'Carolina Panthers': {'name': 'Carolina Panthers',
#   'position': 'DST',
#   'fpros_pre_draft$': '$0'},
#  'Jacksonville Jaguars': {'name': 'Jacksonville Jaguars',
#   'position': 'DST',
#   'fpros_pre_draft$': '$0'},
#  'Kansas City Chiefs': {'name': 'Kansas City Chiefs',
#   'position': 'DST',
#   'fpros_pre_draft$': '$0'},
#  'Arizona Cardinals': {'name': 'Arizona Cardinals',
#   'position': 'DST',
#   'fpros_pre_draft$': '$0'},
#  'Washington Redskins': {'name': 'Washington Redskins',
#   'position': 'DST',
#   'fpros_pre_draft$': '$0'},
#  'Seattle Seahawks': {'name': 'Seattle Seahawks',
#   'position': 'DST',
#   'fpros_pre_draft$': '$0'},
#  'Dallas Cowboys': {'name': 'Dallas Cowboys',
#   'position': 'DST',
#   'fpros_pre_draft$': '$0'},
#  'Green Bay Packers': {'name': 'Green Bay Packers',
#   'position': 'DST',
#   'fpros_pre_draft$': '$0'},
#  'Tennessee Titans': {'name': 'Tennessee Titans',
#   'position': 'DST',
#   'fpros_pre_draft$': '$0'},
#  'New York Jets': {'name': 'New York Jets',
#   'position': 'DST',
#   'fpros_pre_draft$': '$0'},
#  'Atlanta Falcons': {'name': 'Atlanta Falcons',
#   'position': 'DST',
#   'fpros_pre_draft$': '$0'},
#  'San Francisco 49ers': {'name': 'San Francisco 49ers',
#   'position': 'DST',
#   'fpros_pre_draft$': '$0'},
#  'Detroit Lions': {'name': 'Detroit Lions',
#   'position': 'DST',
#   'fpros_pre_draft$': '$0'},
#  'Cincinnati Bengals': {'name': 'Cincinnati Bengals',
#   'position': 'DST',
#   'fpros_pre_draft$': '$0'},
#  'New York Giants': {'name': 'New York Giants',
#   'position': 'DST',
#   'fpros_pre_draft$': '$0'},
#  'Tampa Bay Buccaneers': {'name': 'Tampa Bay Buccaneers',
#   'position': 'DST',
#   'fpros_pre_draft$': '$0'},
#  'Miami Dolphins': {'name': 'Miami Dolphins',
#   'position': 'DST',
#   'fpros_pre_draft$': '$0'},
#  'Oakland Raiders': {'name': 'Oakland Raiders',
#   'position': 'DST',
#   'fpros_pre_draft$': '$0'},
#  'Saquon Barkley, NYG': {'name': 'Saquon Barkley, NYG',
#   'position': 'RB',
#   'fpros_pre_draft$': '$64'},
#  'Christian McCaffrey, CAR': {'name': 'Christian McCaffrey, CAR',
#   'position': 'RB',
#   'fpros_pre_draft$': '$58'},
#  'Alvin Kamara, NO': {'name': 'Alvin Kamara, NO',
#   'position': 'RB',
#   'fpros_pre_draft$': '$57'},
#  'Ezekiel Elliott, DAL': {'name': 'Ezekiel Elliott, DAL',
#   'position': 'RB',
#   'fpros_pre_draft$': '$54'},
#  "Le'Veon Bell, NYJ": {'name': "Le'Veon Bell, NYJ",
#   'position': 'RB',
#   'fpros_pre_draft$': '$45'},
#  'David Johnson, ARI': {'name': 'David Johnson, ARI',
#   'position': 'RB',
#   'fpros_pre_draft$': '$44'},
#  'James Conner, PIT': {'name': 'James Conner, PIT',
#   'position': 'RB',
#   'fpros_pre_draft$': '$44'},
#  'Todd Gurley, LAR': {'name': 'Todd Gurley, LAR',
#   'position': 'RB',
#   'fpros_pre_draft$': '$42'},
#  'Joe Mixon, CIN': {'name': 'Joe Mixon, CIN',
#   'position': 'RB',
#   'fpros_pre_draft$': '$41'},
#  'Nick Chubb, CLE': {'name': 'Nick Chubb, CLE',
#   'position': 'RB',
#   'fpros_pre_draft$': '$40'},
#  'Dalvin Cook, MIN': {'name': 'Dalvin Cook, MIN',
#   'position': 'RB',
#   'fpros_pre_draft$': '$39'},
#  'Damien Williams, KC': {'name': 'Damien Williams, KC',
#   'position': 'RB',
#   'fpros_pre_draft$': '$35'},
#  'Melvin Gordon, LAC': {'name': 'Melvin Gordon, LAC',
#   'position': 'RB',
#   'fpros_pre_draft$': '$34'},
#  'Derrick Henry, TEN': {'name': 'Derrick Henry, TEN',
#   'position': 'RB',
#   'fpros_pre_draft$': '$34'},
#  'Kerryon Johnson, DET': {'name': 'Kerryon Johnson, DET',
#   'position': 'RB',
#   'fpros_pre_draft$': '$34'},
#  'Chris Carson, SEA': {'name': 'Chris Carson, SEA',
#   'position': 'RB',
#   'fpros_pre_draft$': '$34'},
#  'Leonard Fournette, JAC': {'name': 'Leonard Fournette, JAC',
#   'position': 'RB',
#   'fpros_pre_draft$': '$33'},
#  'Marlon Mack, IND': {'name': 'Marlon Mack, IND',
#   'position': 'RB',
#   'fpros_pre_draft$': '$32'},
#  'Aaron Jones, GB': {'name': 'Aaron Jones, GB',
#   'position': 'RB',
#   'fpros_pre_draft$': '$30'},
#  'Devonta Freeman, ATL': {'name': 'Devonta Freeman, ATL',
#   'position': 'RB',
#   'fpros_pre_draft$': '$29'},
#  'Josh Jacobs, OAK': {'name': 'Josh Jacobs, OAK',
#   'position': 'RB',
#   'fpros_pre_draft$': '$28'},
#  'Sony Michel, NE': {'name': 'Sony Michel, NE',
#   'position': 'RB',
#   'fpros_pre_draft$': '$28'},
#  'David Montgomery, CHI': {'name': 'David Montgomery, CHI',
#   'position': 'RB',
#   'fpros_pre_draft$': '$24'},
#  'Mark Ingram, BAL': {'name': 'Mark Ingram, BAL',
#   'position': 'RB',
#   'fpros_pre_draft$': '$24'},
#  'Phillip Lindsay, DEN': {'name': 'Phillip Lindsay, DEN',
#   'position': 'RB',
#   'fpros_pre_draft$': '$22'},
#  'Lamar Miller, HOU': {'name': 'Lamar Miller, HOU',
#   'position': 'RB',
#   'fpros_pre_draft$': '$21'},
#  'Kenyan Drake, MIA': {'name': 'Kenyan Drake, MIA',
#   'position': 'RB',
#   'fpros_pre_draft$': '$19'},
#  'Tevin Coleman, SF': {'name': 'Tevin Coleman, SF',
#   'position': 'RB',
#   'fpros_pre_draft$': '$16'},
#  'James White, NE': {'name': 'James White, NE',
#   'position': 'RB',
#   'fpros_pre_draft$': '$15'},
#  'Derrius Guice, WAS': {'name': 'Derrius Guice, WAS',
#   'position': 'RB',
#   'fpros_pre_draft$': '$13'},
#  'Miles Sanders, PHI': {'name': 'Miles Sanders, PHI',
#   'position': 'RB',
#   'fpros_pre_draft$': '$12'},
#  'Austin Ekeler, LAC': {'name': 'Austin Ekeler, LAC',
#   'position': 'RB',
#   'fpros_pre_draft$': '$12'},
#  'Peyton Barber, TB': {'name': 'Peyton Barber, TB',
#   'position': 'RB',
#   'fpros_pre_draft$': '$12'},
#  'Tarik Cohen, CHI': {'name': 'Tarik Cohen, CHI',
#   'position': 'RB',
#   'fpros_pre_draft$': '$10'},
#  'Latavius Murray, NO': {'name': 'Latavius Murray, NO',
#   'position': 'RB',
#   'fpros_pre_draft$': '$10'},
#  'LeSean McCoy, BUF': {'name': 'LeSean McCoy, BUF',
#   'position': 'RB',
#   'fpros_pre_draft$': '$9'},
#  'Rashaad Penny, SEA': {'name': 'Rashaad Penny, SEA',
#   'position': 'RB',
#   'fpros_pre_draft$': '$9'},
#  'Jordan Howard, PHI': {'name': 'Jordan Howard, PHI',
#   'position': 'RB',
#   'fpros_pre_draft$': '$9'},
#  'Royce Freeman, DEN': {'name': 'Royce Freeman, DEN',
#   'position': 'RB',
#   'fpros_pre_draft$': '$7'},
#  'Darrell Henderson, LAR': {'name': 'Darrell Henderson, LAR',
#   'position': 'RB',
#   'fpros_pre_draft$': '$7'},
#  'Kalen Ballage, MIA': {'name': 'Kalen Ballage, MIA',
#   'position': 'RB',
#   'fpros_pre_draft$': '$6'},
#  'Matt Breida, SF': {'name': 'Matt Breida, SF',
#   'position': 'RB',
#   'fpros_pre_draft$': '$6'},
#  'Duke Johnson, HOU': {'name': 'Duke Johnson, HOU',
#   'position': 'RB',
#   'fpros_pre_draft$': '$6'},
#  'Dion Lewis, TEN': {'name': 'Dion Lewis, TEN',
#   'position': 'RB',
#   'fpros_pre_draft$': '$5'},
#  'Adrian Peterson, WAS': {'name': 'Adrian Peterson, WAS',
#   'position': 'RB',
#   'fpros_pre_draft$': '$5'},
#  'Ronald Jones II, TB': {'name': 'Ronald Jones II, TB',
#   'position': 'RB',
#   'fpros_pre_draft$': '$5'},
#  'Jaylen Samuels, PIT': {'name': 'Jaylen Samuels, PIT',
#   'position': 'RB',
#   'fpros_pre_draft$': '$5'},
#  'C.J. Anderson, DET': {'name': 'C.J. Anderson, DET',
#   'position': 'RB',
#   'fpros_pre_draft$': '$4'},
#  'Nyheim Hines, IND': {'name': 'Nyheim Hines, IND',
#   'position': 'RB',
#   'fpros_pre_draft$': '$4'},
#  'Jamaal Williams, GB': {'name': 'Jamaal Williams, GB',
#   'position': 'RB',
#   'fpros_pre_draft$': '$4'},
#  'Ito Smith, ATL': {'name': 'Ito Smith, ATL',
#   'position': 'RB',
#   'fpros_pre_draft$': '$4'},
#  'Chris Thompson, WAS': {'name': 'Chris Thompson, WAS',
#   'position': 'RB',
#   'fpros_pre_draft$': '$3'},
#  'Jalen Richard, OAK': {'name': 'Jalen Richard, OAK',
#   'position': 'RB',
#   'fpros_pre_draft$': '$3'},
#  'Kareem Hunt, CLE': {'name': 'Kareem Hunt, CLE',
#   'position': 'RB',
#   'fpros_pre_draft$': '$3'},
#  'Giovani Bernard, CIN': {'name': 'Giovani Bernard, CIN',
#   'position': 'RB',
#   'fpros_pre_draft$': '$3'},
#  'Damien Harris, NE': {'name': 'Damien Harris, NE',
#   'position': 'RB',
#   'fpros_pre_draft$': '$3'},
#  'Gus Edwards, BAL': {'name': 'Gus Edwards, BAL',
#   'position': 'RB',
#   'fpros_pre_draft$': '$2'},
#  'Carlos Hyde, KC': {'name': 'Carlos Hyde, KC',
#   'position': 'RB',
#   'fpros_pre_draft$': '$2'},
#  'Devin Singletary, BUF': {'name': 'Devin Singletary, BUF',
#   'position': 'RB',
#   'fpros_pre_draft$': '$2'},
#  'Alexander Mattison, MIN': {'name': 'Alexander Mattison, MIN',
#   'position': 'RB',
#   'fpros_pre_draft$': '$2'},
#  'Jerick McKinnon, SF': {'name': 'Jerick McKinnon, SF',
#   'position': 'RB',
#   'fpros_pre_draft$': '$2'},
#  'Frank Gore, BUF': {'name': 'Frank Gore, BUF',
#   'position': 'RB',
#   'fpros_pre_draft$': '$2'},
#  'Justice Hill, BAL': {'name': 'Justice Hill, BAL',
#   'position': 'RB',
#   'fpros_pre_draft$': '$2'},
#  'Justin Jackson, LAC': {'name': 'Justin Jackson, LAC',
#   'position': 'RB',
#   'fpros_pre_draft$': '$2'},
#  'Rodney Anderson, CIN': {'name': 'Rodney Anderson, CIN',
#   'position': 'RB',
#   'fpros_pre_draft$': '$1'},
#  'Mike Davis, CHI': {'name': 'Mike Davis, CHI',
#   'position': 'RB',
#   'fpros_pre_draft$': '$1'},
#  'Alfred Blue, JAC': {'name': 'Alfred Blue, JAC',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Darwin Thompson, KC': {'name': 'Darwin Thompson, KC',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Tony Pollard, DAL': {'name': 'Tony Pollard, DAL',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Bilal Powell, NYJ': {'name': 'Bilal Powell, NYJ',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Doug Martin, OAK': {'name': 'Doug Martin, OAK',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Chase Edmonds, ARI': {'name': 'Chase Edmonds, ARI',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Rex Burkhead, NE': {'name': 'Rex Burkhead, NE',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Ty Montgomery, NYJ': {'name': 'Ty Montgomery, NYJ',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Zach Zenner, DET': {'name': 'Zach Zenner, DET',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Corey Clement, PHI': {'name': 'Corey Clement, PHI',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Dontrell Hilliard, CLE': {'name': 'Dontrell Hilliard, CLE',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Ty Johnson, DET': {'name': 'Ty Johnson, DET',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Theo Riddick, DEN': {'name': 'Theo Riddick, DEN',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'T.J. Yeldon, BUF': {'name': 'T.J. Yeldon, BUF',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Elijah McGuire, NYJ': {'name': 'Elijah McGuire, NYJ',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Wayne Gallman, NYG': {'name': 'Wayne Gallman, NYG',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Ryquell Armstead, JAC': {'name': 'Ryquell Armstead, JAC',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Malcolm Brown, LAR': {'name': 'Malcolm Brown, LAR',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Cameron Artis-Payne, CAR': {'name': 'Cameron Artis-Payne, CAR',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Brandon Bolden, NE': {'name': 'Brandon Bolden, NE',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Brian Hill, ATL': {'name': 'Brian Hill, ATL',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'J.D. McKissic, SEA': {'name': 'J.D. McKissic, SEA',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Reggie Bonnafon, CAR': {'name': 'Reggie Bonnafon, CAR',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Dexter Williams, GB': {'name': 'Dexter Williams, GB',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Kyle Juszczyk, SF': {'name': 'Kyle Juszczyk, SF',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Jordan Wilkins, IND': {'name': 'Jordan Wilkins, IND',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Andre Ellington, TB': {'name': 'Andre Ellington, TB',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Devontae Booker, DEN': {'name': 'Devontae Booker, DEN',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Josh Ferguson, HOU': {'name': 'Josh Ferguson, HOU',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Darren Sproles, PHI': {'name': 'Darren Sproles, PHI',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Damarea Crockett, HOU': {'name': 'Damarea Crockett, HOU',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Kenneth Dixon, BAL': {'name': 'Kenneth Dixon, BAL',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'Myles Gaskin, MIA': {'name': 'Myles Gaskin, MIA',
#   'position': 'RB',
#   'fpros_pre_draft$': '$0'},
#  'DeAndre Hopkins, HOU': {'name': 'DeAndre Hopkins, HOU',
#   'position': 'WR',
#   'fpros_pre_draft$': '$48'},
#  'Julio Jones, ATL': {'name': 'Julio Jones, ATL',
#   'position': 'WR',
#   'fpros_pre_draft$': '$48'},
#  'Tyreek Hill, KC': {'name': 'Tyreek Hill, KC',
#   'position': 'WR',
#   'fpros_pre_draft$': '$46'},
#  'Davante Adams, GB': {'name': 'Davante Adams, GB',
#   'position': 'WR',
#   'fpros_pre_draft$': '$45'},
#  'JuJu Smith-Schuster, PIT': {'name': 'JuJu Smith-Schuster, PIT',
#   'position': 'WR',
#   'fpros_pre_draft$': '$43'},
#  'Michael Thomas, NO': {'name': 'Michael Thomas, NO',
#   'position': 'WR',
#   'fpros_pre_draft$': '$40'},
#  'Mike Evans, TB': {'name': 'Mike Evans, TB',
#   'position': 'WR',
#   'fpros_pre_draft$': '$39'},
#  'Odell Beckham Jr., CLE': {'name': 'Odell Beckham Jr., CLE',
#   'position': 'WR',
#   'fpros_pre_draft$': '$38'},
#  'Antonio Brown, OAK': {'name': 'Antonio Brown, OAK',
#   'position': 'WR',
#   'fpros_pre_draft$': '$36'},
#  'Keenan Allen, LAC': {'name': 'Keenan Allen, LAC',
#   'position': 'WR',
#   'fpros_pre_draft$': '$34'},
#  'T.Y. Hilton, IND': {'name': 'T.Y. Hilton, IND',
#   'position': 'WR',
#   'fpros_pre_draft$': '$32'},
#  'Adam Thielen, MIN': {'name': 'Adam Thielen, MIN',
#   'position': 'WR',
#   'fpros_pre_draft$': '$30'},
#  'Brandin Cooks, LAR': {'name': 'Brandin Cooks, LAR',
#   'position': 'WR',
#   'fpros_pre_draft$': '$29'},
#  'Julian Edelman, NE': {'name': 'Julian Edelman, NE',
#   'position': 'WR',
#   'fpros_pre_draft$': '$29'},
#  'Amari Cooper, DAL': {'name': 'Amari Cooper, DAL',
#   'position': 'WR',
#   'fpros_pre_draft$': '$28'},
#  'Robert Woods, LAR': {'name': 'Robert Woods, LAR',
#   'position': 'WR',
#   'fpros_pre_draft$': '$27'},
#  'Stefon Diggs, MIN': {'name': 'Stefon Diggs, MIN',
#   'position': 'WR',
#   'fpros_pre_draft$': '$27'},
#  'Tyler Lockett, SEA': {'name': 'Tyler Lockett, SEA',
#   'position': 'WR',
#   'fpros_pre_draft$': '$26'},
#  'Kenny Golladay, DET': {'name': 'Kenny Golladay, DET',
#   'position': 'WR',
#   'fpros_pre_draft$': '$24'},
#  'Cooper Kupp, LAR': {'name': 'Cooper Kupp, LAR',
#   'position': 'WR',
#   'fpros_pre_draft$': '$22'},
#  'Chris Godwin, TB': {'name': 'Chris Godwin, TB',
#   'position': 'WR',
#   'fpros_pre_draft$': '$21'},
#  'Mike Williams, LAC': {'name': 'Mike Williams, LAC',
#   'position': 'WR',
#   'fpros_pre_draft$': '$20'},
#  'Tyler Boyd, CIN': {'name': 'Tyler Boyd, CIN',
#   'position': 'WR',
#   'fpros_pre_draft$': '$20'},
#  'Alshon Jeffery, PHI': {'name': 'Alshon Jeffery, PHI',
#   'position': 'WR',
#   'fpros_pre_draft$': '$18'},
#  'A.J. Green, CIN': {'name': 'A.J. Green, CIN',
#   'position': 'WR',
#   'fpros_pre_draft$': '$18'},
#  'Allen Robinson, CHI': {'name': 'Allen Robinson, CHI',
#   'position': 'WR',
#   'fpros_pre_draft$': '$16'},
#  'D.J. Moore, CAR': {'name': 'D.J. Moore, CAR',
#   'position': 'WR',
#   'fpros_pre_draft$': '$16'},
#  'Sammy Watkins, KC': {'name': 'Sammy Watkins, KC',
#   'position': 'WR',
#   'fpros_pre_draft$': '$16'},
#  'Calvin Ridley, ATL': {'name': 'Calvin Ridley, ATL',
#   'position': 'WR',
#   'fpros_pre_draft$': '$16'},
#  'Robby Anderson, NYJ': {'name': 'Robby Anderson, NYJ',
#   'position': 'WR',
#   'fpros_pre_draft$': '$14'},
#  'Josh Gordon, NE': {'name': 'Josh Gordon, NE',
#   'position': 'WR',
#   'fpros_pre_draft$': '$14'},
#  'Jarvis Landry, CLE': {'name': 'Jarvis Landry, CLE',
#   'position': 'WR',
#   'fpros_pre_draft$': '$14'},
#  'Marvin Jones, DET': {'name': 'Marvin Jones, DET',
#   'position': 'WR',
#   'fpros_pre_draft$': '$13'},
#  'Christian Kirk, ARI': {'name': 'Christian Kirk, ARI',
#   'position': 'WR',
#   'fpros_pre_draft$': '$12'},
#  'Dante Pettis, SF': {'name': 'Dante Pettis, SF',
#   'position': 'WR',
#   'fpros_pre_draft$': '$12'},
#  'Sterling Shepard, NYG': {'name': 'Sterling Shepard, NYG',
#   'position': 'WR',
#   'fpros_pre_draft$': '$11'},
#  'Will Fuller, HOU': {'name': 'Will Fuller, HOU',
#   'position': 'WR',
#   'fpros_pre_draft$': '$11'},
#  'Curtis Samuel, CAR': {'name': 'Curtis Samuel, CAR',
#   'position': 'WR',
#   'fpros_pre_draft$': '$11'},
#  'Dede Westbrook, JAC': {'name': 'Dede Westbrook, JAC',
#   'position': 'WR',
#   'fpros_pre_draft$': '$10'},
#  'Emmanuel Sanders, DEN': {'name': 'Emmanuel Sanders, DEN',
#   'position': 'WR',
#   'fpros_pre_draft$': '$10'},
#  'Corey Davis, TEN': {'name': 'Corey Davis, TEN',
#   'position': 'WR',
#   'fpros_pre_draft$': '$10'},
#  'Larry Fitzgerald, ARI': {'name': 'Larry Fitzgerald, ARI',
#   'position': 'WR',
#   'fpros_pre_draft$': '$8'},
#  'Kenny Stills, MIA': {'name': 'Kenny Stills, MIA',
#   'position': 'WR',
#   'fpros_pre_draft$': '$7'},
#  'Courtland Sutton, DEN': {'name': 'Courtland Sutton, DEN',
#   'position': 'WR',
#   'fpros_pre_draft$': '$7'},
#  'DeSean Jackson, PHI': {'name': 'DeSean Jackson, PHI',
#   'position': 'WR',
#   'fpros_pre_draft$': '$7'},
#  'Mohamed Sanu, ATL': {'name': 'Mohamed Sanu, ATL',
#   'position': 'WR',
#   'fpros_pre_draft$': '$6'},
#  'Michael Gallup, DAL': {'name': 'Michael Gallup, DAL',
#   'position': 'WR',
#   'fpros_pre_draft$': '$6'},
#  'Donte Moncrief, PIT': {'name': 'Donte Moncrief, PIT',
#   'position': 'WR',
#   'fpros_pre_draft$': '$6'},
#  'Jamison Crowder, NYJ': {'name': 'Jamison Crowder, NYJ',
#   'position': 'WR',
#   'fpros_pre_draft$': '$5'},
#  'Tyrell Williams, OAK': {'name': 'Tyrell Williams, OAK',
#   'position': 'WR',
#   'fpros_pre_draft$': '$5'},
#  'Geronimo Allison, GB': {'name': 'Geronimo Allison, GB',
#   'position': 'WR',
#   'fpros_pre_draft$': '$5'},
#  'Ted Ginn, NO': {'name': 'Ted Ginn, NO',
#   'position': 'WR',
#   'fpros_pre_draft$': '$5'},
#  'John Brown, BUF': {'name': 'John Brown, BUF',
#   'position': 'WR',
#   'fpros_pre_draft$': '$4'},
#  'Marquez Valdes-Scantling, GB': {'name': 'Marquez Valdes-Scantling, GB',
#   'position': 'WR',
#   'fpros_pre_draft$': '$4'},
#  'Devin Funchess, IND': {'name': 'Devin Funchess, IND',
#   'position': 'WR',
#   'fpros_pre_draft$': '$4'},
#  'Anthony Miller, CHI': {'name': 'Anthony Miller, CHI',
#   'position': 'WR',
#   'fpros_pre_draft$': '$3'},
#  'Albert Wilson, MIA': {'name': 'Albert Wilson, MIA',
#   'position': 'WR',
#   'fpros_pre_draft$': '$3'},
#  'DaeSean Hamilton, DEN': {'name': 'DaeSean Hamilton, DEN',
#   'position': 'WR',
#   'fpros_pre_draft$': '$3'},
#  'Devante Parker, MIA': {'name': 'Devante Parker, MIA',
#   'position': 'WR',
#   'fpros_pre_draft$': '$2'},
#  'James Washington, PIT': {'name': 'James Washington, PIT',
#   'position': 'WR',
#   'fpros_pre_draft$': '$2'},
#  'Keke Coutee, HOU': {'name': 'Keke Coutee, HOU',
#   'position': 'WR',
#   'fpros_pre_draft$': '$2'},
#  'D.K. Metcalf, SEA': {'name': 'D.K. Metcalf, SEA',
#   'position': 'WR',
#   'fpros_pre_draft$': '$2'},
#  'Golden Tate, NYG': {'name': 'Golden Tate, NYG',
#   'position': 'WR',
#   'fpros_pre_draft$': '$2'},
#  'Marquise Goodwin, SF': {'name': 'Marquise Goodwin, SF',
#   'position': 'WR',
#   'fpros_pre_draft$': '$2'},
#  'Adam Humphries, TEN': {'name': 'Adam Humphries, TEN',
#   'position': 'WR',
#   'fpros_pre_draft$': '$1'},
#  'Marqise Lee, JAC': {'name': 'Marqise Lee, JAC',
#   'position': 'WR',
#   'fpros_pre_draft$': '$1'},
#  'Paul Richardson, WAS': {'name': 'Paul Richardson, WAS',
#   'position': 'WR',
#   'fpros_pre_draft$': '$1'},
#  'Zay Jones, BUF': {'name': 'Zay Jones, BUF',
#   'position': 'WR',
#   'fpros_pre_draft$': '$1'},
#  'Marquise Brown, BAL': {'name': 'Marquise Brown, BAL',
#   'position': 'WR',
#   'fpros_pre_draft$': '$1'},
#  'Robert Foster, BUF': {'name': 'Robert Foster, BUF',
#   'position': 'WR',
#   'fpros_pre_draft$': '$1'},
#  'Deebo Samuel, SF': {'name': 'Deebo Samuel, SF',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'Taylor Gabriel, CHI': {'name': 'Taylor Gabriel, CHI',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'Quincy Enunwa, NYJ': {'name': 'Quincy Enunwa, NYJ',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'Parris Campbell, IND': {'name': 'Parris Campbell, IND',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'Josh Doctson, WAS': {'name': 'Josh Doctson, WAS',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'Danny Amendola, DET': {'name': 'Danny Amendola, DET',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  "Tre'Quan Smith, NO": {'name': "Tre'Quan Smith, NO",
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'David Moore, SEA': {'name': 'David Moore, SEA',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'Cole Beasley, BUF': {'name': 'Cole Beasley, BUF',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'Willie Snead, BAL': {'name': 'Willie Snead, BAL',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'Randall Cobb, DAL': {'name': 'Randall Cobb, DAL',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'Rashard Higgins, CLE': {'name': 'Rashard Higgins, CLE',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'Nelson Agholor, PHI': {'name': 'Nelson Agholor, PHI',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'Breshad Perriman, TB': {'name': 'Breshad Perriman, TB',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  "N'Keal Harry, NE": {'name': "N'Keal Harry, NE",
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'Chris Conley, JAC': {'name': 'Chris Conley, JAC',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'Miles Boykin, BAL': {'name': 'Miles Boykin, BAL',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'John Ross, CIN': {'name': 'John Ross, CIN',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'A.J. Brown, TEN': {'name': 'A.J. Brown, TEN',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'Andy Isabella, ARI': {'name': 'Andy Isabella, ARI',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'Mecole Hardman, KC': {'name': 'Mecole Hardman, KC',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'Terry McLaurin, WAS': {'name': 'Terry McLaurin, WAS',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'Travis Benjamin, LAC': {'name': 'Travis Benjamin, LAC',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'Trey Quinn, WAS': {'name': 'Trey Quinn, WAS',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'Cody Latimer, NYG': {'name': 'Cody Latimer, NYG',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'D.J. Chark, JAC': {'name': 'D.J. Chark, JAC',
#   'position': 'WR',
#   'fpros_pre_draft$': '$0'},
#  'Travis Kelce, KC': {'name': 'Travis Kelce, KC',
#   'position': 'TE',
#   'fpros_pre_draft$': '$39'},
#  'George Kittle, SF': {'name': 'George Kittle, SF',
#   'position': 'TE',
#   'fpros_pre_draft$': '$30'},
#  'Zach Ertz, PHI': {'name': 'Zach Ertz, PHI',
#   'position': 'TE',
#   'fpros_pre_draft$': '$24'},
#  'O.J. Howard, TB': {'name': 'O.J. Howard, TB',
#   'position': 'TE',
#   'fpros_pre_draft$': '$17'},
#  'Jared Cook, NO': {'name': 'Jared Cook, NO',
#   'position': 'TE',
#   'fpros_pre_draft$': '$15'},
#  'Evan Engram, NYG': {'name': 'Evan Engram, NYG',
#   'position': 'TE',
#   'fpros_pre_draft$': '$14'},
#  'Hunter Henry, LAC': {'name': 'Hunter Henry, LAC',
#   'position': 'TE',
#   'fpros_pre_draft$': '$12'},
#  'Vance McDonald, PIT': {'name': 'Vance McDonald, PIT',
#   'position': 'TE',
#   'fpros_pre_draft$': '$9'},
#  'Eric Ebron, IND': {'name': 'Eric Ebron, IND',
#   'position': 'TE',
#   'fpros_pre_draft$': '$8'},
#  'David Njoku, CLE': {'name': 'David Njoku, CLE',
#   'position': 'TE',
#   'fpros_pre_draft$': '$7'},
#  'Delanie Walker, TEN': {'name': 'Delanie Walker, TEN',
#   'position': 'TE',
#   'fpros_pre_draft$': '$5'},
#  'Jordan Reed, WAS': {'name': 'Jordan Reed, WAS',
#   'position': 'TE',
#   'fpros_pre_draft$': '$5'},
#  'Mark Andrews, BAL': {'name': 'Mark Andrews, BAL',
#   'position': 'TE',
#   'fpros_pre_draft$': '$5'},
#  'Austin Hooper, ATL': {'name': 'Austin Hooper, ATL',
#   'position': 'TE',
#   'fpros_pre_draft$': '$5'},
#  'Jimmy Graham, GB': {'name': 'Jimmy Graham, GB',
#   'position': 'TE',
#   'fpros_pre_draft$': '$3'},
#  'Greg Olsen, CAR': {'name': 'Greg Olsen, CAR',
#   'position': 'TE',
#   'fpros_pre_draft$': '$3'},
#  'Trey Burton, CHI': {'name': 'Trey Burton, CHI',
#   'position': 'TE',
#   'fpros_pre_draft$': '$3'},
#  'Kyle Rudolph, MIN': {'name': 'Kyle Rudolph, MIN',
#   'position': 'TE',
#   'fpros_pre_draft$': '$3'},
#  'Jack Doyle, IND': {'name': 'Jack Doyle, IND',
#   'position': 'TE',
#   'fpros_pre_draft$': '$2'},
#  'Noah Fant, DEN': {'name': 'Noah Fant, DEN',
#   'position': 'TE',
#   'fpros_pre_draft$': '$1'},
#  'T.J. Hockenson, DET': {'name': 'T.J. Hockenson, DET',
#   'position': 'TE',
#   'fpros_pre_draft$': '$1'},
#  'Tyler Eifert, CIN': {'name': 'Tyler Eifert, CIN',
#   'position': 'TE',
#   'fpros_pre_draft$': '$1'},
#  'Jason Witten, DAL': {'name': 'Jason Witten, DAL',
#   'position': 'TE',
#   'fpros_pre_draft$': '$0'},
#  'Chris Herndon IV, NYJ': {'name': 'Chris Herndon IV, NYJ',
#   'position': 'TE',
#   'fpros_pre_draft$': '$0'},
#  'Dallas Goedert, PHI': {'name': 'Dallas Goedert, PHI',
#   'position': 'TE',
#   'fpros_pre_draft$': '$0'},
#  'Darren Waller, OAK': {'name': 'Darren Waller, OAK',
#   'position': 'TE',
#   'fpros_pre_draft$': '$0'},
#  'Will Dissly, SEA': {'name': 'Will Dissly, SEA',
#   'position': 'TE',
#   'fpros_pre_draft$': '$0'},
#  'Greg Zuerlein, LAR': {'name': 'Greg Zuerlein, LAR',
#   'position': 'K',
#   'fpros_pre_draft$': '$1'},
#  'Justin Tucker, BAL': {'name': 'Justin Tucker, BAL',
#   'position': 'K',
#   'fpros_pre_draft$': '$1'},
#  'Stephen Gostkowski, NE': {'name': 'Stephen Gostkowski, NE',
#   'position': 'K',
#   'fpros_pre_draft$': '$1'},
#  'Wil Lutz, NO': {'name': 'Wil Lutz, NO',
#   'position': 'K',
#   'fpros_pre_draft$': '$1'},
#  'Harrison Butker, KC': {'name': 'Harrison Butker, KC',
#   'position': 'K',
#   'fpros_pre_draft$': '$1'},
#  "Ka'imi Fairbairn, HOU": {'name': "Ka'imi Fairbairn, HOU",
#   'position': 'K',
#   'fpros_pre_draft$': '$1'},
#  'Robbie Gould, SF': {'name': 'Robbie Gould, SF',
#   'position': 'K',
#   'fpros_pre_draft$': '$1'},
#  'Michael Badgley, LAC': {'name': 'Michael Badgley, LAC',
#   'position': 'K',
#   'fpros_pre_draft$': '$1'},
#  'Matt Gay, TB': {'name': 'Matt Gay, TB',
#   'position': 'K',
#   'fpros_pre_draft$': '$1'},
#  'Adam Vinatieri, IND': {'name': 'Adam Vinatieri, IND',
#   'position': 'K',
#   'fpros_pre_draft$': '$1'},
#  'Jake Elliott, PHI': {'name': 'Jake Elliott, PHI',
#   'position': 'K',
#   'fpros_pre_draft$': '$1'},
#  'Brett Maher, DAL': {'name': 'Brett Maher, DAL',
#   'position': 'K',
#   'fpros_pre_draft$': '$1'},
#  'Mason Crosby, GB': {'name': 'Mason Crosby, GB',
#   'position': 'K',
#   'fpros_pre_draft$': '$1'},
#  'Giorgio Tavecchio, ATL': {'name': 'Giorgio Tavecchio, ATL',
#   'position': 'K',
#   'fpros_pre_draft$': '$1'},
#  'Matt Prater, DET': {'name': 'Matt Prater, DET',
#   'position': 'K',
#   'fpros_pre_draft$': '$0'},
#  'Austin Seibert, CLE': {'name': 'Austin Seibert, CLE',
#   'position': 'K',
#   'fpros_pre_draft$': '$0'},
#  'Ryan Succop, TEN': {'name': 'Ryan Succop, TEN',
#   'position': 'K',
#   'fpros_pre_draft$': '$0'},
#  'Jason Myers, SEA': {'name': 'Jason Myers, SEA',
#   'position': 'K',
#   'fpros_pre_draft$': '$0'},
#  'Graham Gano, CAR': {'name': 'Graham Gano, CAR',
#   'position': 'K',
#   'fpros_pre_draft$': '$0'}}

# %%
len(fpros_players)
# Out:
# 305

# %% [markdown]
# ### ESPN Values

# %%
with open('./espn_values.txt') as f:
    lines2 = f.readlines()

# %%
lines2[4].split(') ')
# Out:
# ['5. (86',
#  'Cam Newton, CAR $4 7 5. (5',
#  'David Johnson, ARI $53 12 82. (265',
#  'Alfred Morris, DAL $0 8 72. (196',
#  'Mecole Hardman, KC $0 12\n']

# %%
espn_players = {}
for line in lines2:
    for one_entry in line.split(') ')[1:]:
        try:
            final_split = one_entry.split(' $')
            player = final_split[0]
            pre_draft = final_split[1][:2]

            espn_players[player] = {'name': player,
                                   'espn_pre_draft$': pre_draft}
        except:
            print('!!!!!!!!!!!!!!', one_entry)
# Out:
# !!!!!!!!!!!!!! Bears D/ST (Wk 1: GB
# !!!!!!!!!!!!!! $1 6
#
# !!!!!!!!!!!!!! Jaguars D/ST (Wk 1: KC
# !!!!!!!!!!!!!! $1 10
#
# !!!!!!!!!!!!!! Bills D/ST (Wk 1: @NYJ
# !!!!!!!!!!!!!! $1 6
#
# !!!!!!!!!!!!!! Rams D/ST (Wk 1: @CAR
# !!!!!!!!!!!!!! $1 9
#
# !!!!!!!!!!!!!! Vikings D/ST (Wk 1: ATL
# !!!!!!!!!!!!!! $1 12
#
# !!!!!!!!!!!!!! Saints D/ST (Wk 1: HOU
# !!!!!!!!!!!!!! $1 9
#
# !!!!!!!!!!!!!! Chargers D/ST (Wk 1: IND
# !!!!!!!!!!!!!! $1 12
#
# !!!!!!!!!!!!!! Patriots D/ST (Wk 1: PIT
# !!!!!!!!!!!!!! $1 10
#
# !!!!!!!!!!!!!! Colts D/ST (Wk 1: @LAC
# !!!!!!!!!!!!!! $1 6
#
# !!!!!!!!!!!!!! Titans D/ST (Wk 1: @CLE
# !!!!!!!!!!!!!! $1 11
#
# !!!!!!!!!!!!!! Broncos D/ST (Wk 1: @OAK
# !!!!!!!!!!!!!! $1 10
#
# !!!!!!!!!!!!!! Texans D/ST (Wk 1: @NO
# !!!!!!!!!!!!!! $1 10
#
# !!!!!!!!!!!!!! Eagles D/ST (Wk 1: WAS
# !!!!!!!!!!!!!! $0 10
#
# !!!!!!!!!!!!!! Browns D/ST (Wk 1: TEN
# !!!!!!!!!!!!!! $0 7
#
# !!!!!!!!!!!!!! Ravens D/ST (Wk 1: @MIA
# !!!!!!!!!!!!!! $0 8

# %%
len(espn_players)
# Out:
# 265

# %% [markdown]
# ### Check how they vibe

# %%
keys_not_in_fpros = []
for key in espn_players:
    if key not in fpros_players.keys():
        print(key)
        keys_not_in_fpros.append( key )
# Out:
# Alfred Morris, DAL
# Todd Gurley II, LAR
# Ted Ginn Jr., NO
# Hakeem Butler, ARI
# DeVante Parker, MIA
# Willie Snead IV, BAL
# Mitchell Trubisky, CHI
# Mark Ingram II, BAL
# JJ Arcega-Whiteside, PHI
# Diontae Johnson, PIT
# Josh Rosen, MIA
# Case Keenum, WAS
# DJ Moore, CAR
# Daniel Jones, NYG
# Drew Lock, DEN
# Colt McCoy, WAS
# Taysom Hill, NO
# Ronald Jones, TB
# Jacoby Brissett, IND
# Duke Johnson Jr., HOU
# Nick Mullens, SF
# Marvin Jones Jr., DET
# Will Fuller V, HOU
# Mike Badgley, LAC
# Aldrick Rosas, NYG
# Mark Walton, MIA
# Chris Herndon, NYJ
# DK Metcalf, SEA
# Mike Gesicki, MIA
# Gerald Everett, LAR
# Benjamin Watson, NE
# Matt LaCosse, NE
# Jordan Thomas, HOU
# Hayden Hurst, BAL
# Benny Snell Jr., PIT
# DJ Chark, JAC
# Dawson Knox, BUF
# Vernon Davis, WAS

# %%
for check_key in keys_not_in_fpros:
    if int(espn_players[check_key]['espn_pre_draft$']) >= 5:
        print(espn_players[check_key])
# Out:
# {'name': 'Todd Gurley II, LAR', 'espn_pre_draft$': '41'}
# {'name': 'Mark Ingram II, BAL', 'espn_pre_draft$': '17'}
# {'name': 'DJ Moore, CAR', 'espn_pre_draft$': '12'}
# {'name': 'Marvin Jones Jr., DET', 'espn_pre_draft$': '5 '}

# %% [markdown]
# - Let's make sure we rectify these at least

# %%
keys_not_in_espn = []
for key in fpros_players:
    if key not in espn_players.keys():
        print(key)
        keys_not_in_espn.append( key )
# Out:
# Mitch Trubisky, CHI
# Chicago Bears
# Los Angeles Rams
# New Orleans Saints
# Baltimore Ravens
# Cleveland Browns
# Minnesota Vikings
# Indianapolis Colts
# Pittsburgh Steelers
# Philadelphia Eagles
# Los Angeles Chargers
# Buffalo Bills
# Denver Broncos
# Houston Texans
# New England Patriots
# Carolina Panthers
# Jacksonville Jaguars
# Kansas City Chiefs
# Arizona Cardinals
# Washington Redskins
# Seattle Seahawks
# Dallas Cowboys
# Green Bay Packers
# Tennessee Titans
# New York Jets
# Atlanta Falcons
# San Francisco 49ers
# Detroit Lions
# Cincinnati Bengals
# New York Giants
# Tampa Bay Buccaneers
# Miami Dolphins
# Oakland Raiders
# Todd Gurley, LAR
# Mark Ingram, BAL
# Duke Johnson, HOU
# Ronald Jones II, TB
# Rodney Anderson, CIN
# Zach Zenner, DET
# Corey Clement, PHI
# Ty Johnson, DET
# Elijah McGuire, NYJ
# Cameron Artis-Payne, CAR
# Brandon Bolden, NE
# Brian Hill, ATL
# J.D. McKissic, SEA
# Reggie Bonnafon, CAR
# Kyle Juszczyk, SF
# Jordan Wilkins, IND
# Devontae Booker, DEN
# Josh Ferguson, HOU
# Damarea Crockett, HOU
# Kenneth Dixon, BAL
# Myles Gaskin, MIA
# D.J. Moore, CAR
# Marvin Jones, DET
# Will Fuller, HOU
# Ted Ginn, NO
# Devante Parker, MIA
# D.K. Metcalf, SEA
# Marquise Goodwin, SF
# Marqise Lee, JAC
# Taylor Gabriel, CHI
# Danny Amendola, DET
# David Moore, SEA
# Willie Snead, BAL
# Breshad Perriman, TB
# Miles Boykin, BAL
# Travis Benjamin, LAC
# Cody Latimer, NYG
# D.J. Chark, JAC
# Chris Herndon IV, NYJ
# Michael Badgley, LAC
# Matt Gay, TB
# Giorgio Tavecchio, ATL
# Austin Seibert, CLE
# Jason Myers, SEA
# Graham Gano, CAR

# %%
for check_key in keys_not_in_espn:
    if int(fpros_players[check_key]['fpros_pre_draft$'][1:]) >= 5:
        print(fpros_players[check_key])
# Out:
# {'name': 'Mitch Trubisky, CHI', 'position': 'QB', 'fpros_pre_draft$': '$6'}
# {'name': 'Todd Gurley, LAR', 'position': 'RB', 'fpros_pre_draft$': '$42'}
# {'name': 'Mark Ingram, BAL', 'position': 'RB', 'fpros_pre_draft$': '$24'}
# {'name': 'Duke Johnson, HOU', 'position': 'RB', 'fpros_pre_draft$': '$6'}
# {'name': 'Ronald Jones II, TB', 'position': 'RB', 'fpros_pre_draft$': '$5'}
# {'name': 'D.J. Moore, CAR', 'position': 'WR', 'fpros_pre_draft$': '$16'}
# {'name': 'Marvin Jones, DET', 'position': 'WR', 'fpros_pre_draft$': '$13'}
# {'name': 'Will Fuller, HOU', 'position': 'WR', 'fpros_pre_draft$': '$11'}
# {'name': 'Ted Ginn, NO', 'position': 'WR', 'fpros_pre_draft$': '$5'}

# %% [markdown]
# - Make sure to rectify

# %% [markdown]
# ### Let's Map ESPN to FPros

# %%
espn_players['Ted Ginn Jr., NO']
# Out:
# {'name': 'Ted Ginn Jr., NO', 'espn_pre_draft$': '0 '}

# %%
fpros_players['Ted Ginn, NO']
# Out:
# {'name': 'Ted Ginn, NO', 'position': 'WR', 'fpros_pre_draft$': '$5'}

# %%
# {espn_name: fpros_name}

# %%
espn_to_fpros = {'Todd Gurley II, LAR': 'Todd Gurley, LAR',
                'Mark Ingram II, BAL': 'Mark Ingram, BAL',
                'DJ Moore, CAR': 'D.J. Moore, CAR',
                'Marvin Jones Jr., DET': 'Marvin Jones, DET',
                'Mitchell Trubisky, CHI': 'Mitch Trubisky, CHI',
                'Duke Johnson Jr., HOU': 'Duke Johnson, HOU',
                'Ronald Jones, TB': 'Ronald Jones II, TB',
                'Will Fuller V, HOU': 'Will Fuller, HOU',
                'Ted Ginn Jr., NO': 'Ted Ginn, NO'}

# %%
for player in espn_players:
    if player in espn_to_fpros:
        sub_player = espn_to_fpros[player]
        fpros_players[sub_player]['espn_pre_draft$'] = espn_players[player]['espn_pre_draft$']
        continue
    try:
        fpros_players[player]['espn_pre_draft$'] = espn_players[player]['espn_pre_draft$']
    except:
        print('Skipping ', player)
# Out:
# Skipping  Alfred Morris, DAL
# Skipping  Hakeem Butler, ARI
# Skipping  DeVante Parker, MIA
# Skipping  Willie Snead IV, BAL
# Skipping  JJ Arcega-Whiteside, PHI
# Skipping  Diontae Johnson, PIT
# Skipping  Josh Rosen, MIA
# Skipping  Case Keenum, WAS
# Skipping  Daniel Jones, NYG
# Skipping  Drew Lock, DEN
# Skipping  Colt McCoy, WAS
# Skipping  Taysom Hill, NO
# Skipping  Jacoby Brissett, IND
# Skipping  Nick Mullens, SF
# Skipping  Mike Badgley, LAC
# Skipping  Aldrick Rosas, NYG
# Skipping  Mark Walton, MIA
# Skipping  Chris Herndon, NYJ
# Skipping  DK Metcalf, SEA
# Skipping  Mike Gesicki, MIA
# Skipping  Gerald Everett, LAR
# Skipping  Benjamin Watson, NE
# Skipping  Matt LaCosse, NE
# Skipping  Jordan Thomas, HOU
# Skipping  Hayden Hurst, BAL
# Skipping  Benny Snell Jr., PIT
# Skipping  DJ Chark, JAC
# Skipping  Dawson Knox, BUF
# Skipping  Vernon Davis, WAS

# %%
all_players = fpros_players.copy()

# %%
for player in all_players:
    try:
        all_players[player]['espn_pre_draft$'] = all_players[player]['espn_pre_draft$'].replace('$','').strip()
        all_players[player]['fpros_pre_draft$'] = all_players[player]['fpros_pre_draft$'].replace('$','').strip()
    except:
        print('Setting ', player, 'to None')
        all_players[player]['espn_pre_draft$'] = None
        all_players[player]['fpros_pre_draft$'] = all_players[player]['fpros_pre_draft$'].replace('$','').strip()
# Out:
# Setting  Chicago Bears to None
# Setting  Los Angeles Rams to None
# Setting  New Orleans Saints to None
# Setting  Baltimore Ravens to None
# Setting  Cleveland Browns to None
# Setting  Minnesota Vikings to None
# Setting  Indianapolis Colts to None
# Setting  Pittsburgh Steelers to None
# Setting  Philadelphia Eagles to None
# Setting  Los Angeles Chargers to None
# Setting  Buffalo Bills to None
# Setting  Denver Broncos to None
# Setting  Houston Texans to None
# Setting  New England Patriots to None
# Setting  Carolina Panthers to None
# Setting  Jacksonville Jaguars to None
# Setting  Kansas City Chiefs to None
# Setting  Arizona Cardinals to None
# Setting  Washington Redskins to None
# Setting  Seattle Seahawks to None
# Setting  Dallas Cowboys to None
# Setting  Green Bay Packers to None
# Setting  Tennessee Titans to None
# Setting  New York Jets to None
# Setting  Atlanta Falcons to None
# Setting  San Francisco 49ers to None
# Setting  Detroit Lions to None
# Setting  Cincinnati Bengals to None
# Setting  New York Giants to None
# Setting  Tampa Bay Buccaneers to None
# Setting  Miami Dolphins to None
# Setting  Oakland Raiders to None
# Setting  Rodney Anderson, CIN to None
# Setting  Zach Zenner, DET to None
# Setting  Corey Clement, PHI to None
# Setting  Ty Johnson, DET to None
# Setting  Elijah McGuire, NYJ to None
# Setting  Cameron Artis-Payne, CAR to None
# Setting  Brandon Bolden, NE to None
# Setting  Brian Hill, ATL to None
# Setting  J.D. McKissic, SEA to None
# Setting  Reggie Bonnafon, CAR to None
# Setting  Kyle Juszczyk, SF to None
# Setting  Jordan Wilkins, IND to None
# Setting  Devontae Booker, DEN to None
# Setting  Josh Ferguson, HOU to None
# Setting  Damarea Crockett, HOU to None
# Setting  Kenneth Dixon, BAL to None
# Setting  Myles Gaskin, MIA to None
# Setting  Devante Parker, MIA to None
# Setting  D.K. Metcalf, SEA to None
# Setting  Marquise Goodwin, SF to None
# Setting  Marqise Lee, JAC to None
# Setting  Taylor Gabriel, CHI to None
# Setting  Danny Amendola, DET to None
# Setting  David Moore, SEA to None
# Setting  Willie Snead, BAL to None
# Setting  Breshad Perriman, TB to None
# Setting  Miles Boykin, BAL to None
# Setting  Travis Benjamin, LAC to None
# Setting  Cody Latimer, NYG to None
# Setting  D.J. Chark, JAC to None
# Setting  Chris Herndon IV, NYJ to None
# Setting  Michael Badgley, LAC to None
# Setting  Matt Gay, TB to None
# Setting  Giorgio Tavecchio, ATL to None
# Setting  Austin Seibert, CLE to None
# Setting  Jason Myers, SEA to None
# Setting  Graham Gano, CAR to None

# %%
import pickle

# %%
all_players
# Out:
# {'Patrick Mahomes, KC': {'name': 'Patrick Mahomes, KC',
#   'position': 'QB',
#   'fpros_pre_draft$': '31',
#   'espn_pre_draft$': '18'},
#  'Deshaun Watson, HOU': {'name': 'Deshaun Watson, HOU',
#   'position': 'QB',
#   'fpros_pre_draft$': '22',
#   'espn_pre_draft$': '6'},
#  'Aaron Rodgers, GB': {'name': 'Aaron Rodgers, GB',
#   'position': 'QB',
#   'fpros_pre_draft$': '18',
#   'espn_pre_draft$': '6'},
#  'Matt Ryan, ATL': {'name': 'Matt Ryan, ATL',
#   'position': 'QB',
#   'fpros_pre_draft$': '16',
#   'espn_pre_draft$': '6'},
#  'Cam Newton, CAR': {'name': 'Cam Newton, CAR',
#   'position': 'QB',
#   'fpros_pre_draft$': '14',
#   'espn_pre_draft$': '4'},
#  'Andrew Luck, IND': {'name': 'Andrew Luck, IND',
#   'position': 'QB',
#   'fpros_pre_draft$': '12',
#   'espn_pre_draft$': '3'},
#  'Drew Brees, NO': {'name': 'Drew Brees, NO',
#   'position': 'QB',
#   'fpros_pre_draft$': '11',
#   'espn_pre_draft$': '2'},
#  'Jameis Winston, TB': {'name': 'Jameis Winston, TB',
#   'position': 'QB',
#   'fpros_pre_draft$': '10',
#   'espn_pre_draft$': '0'},
#  'Dak Prescott, DAL': {'name': 'Dak Prescott, DAL',
#   'position': 'QB',
#   'fpros_pre_draft$': '10',
#   'espn_pre_draft$': '2'},
#  'Carson Wentz, PHI': {'name': 'Carson Wentz, PHI',
#   'position': 'QB',
#   'fpros_pre_draft$': '10',
#   'espn_pre_draft$': '3'},
#  'Baker Mayfield, CLE': {'name': 'Baker Mayfield, CLE',
#   'position': 'QB',
#   'fpros_pre_draft$': '10',
#   'espn_pre_draft$': '3'},
#  'Jared Goff, LAR': {'name': 'Jared Goff, LAR',
#   'position': 'QB',
#   'fpros_pre_draft$': '9',
#   'espn_pre_draft$': '2'},
#  'Ben Roethlisberger, PIT': {'name': 'Ben Roethlisberger, PIT',
#   'position': 'QB',
#   'fpros_pre_draft$': '9',
#   'espn_pre_draft$': '2'},
#  'Lamar Jackson, BAL': {'name': 'Lamar Jackson, BAL',
#   'position': 'QB',
#   'fpros_pre_draft$': '7',
#   'espn_pre_draft$': '2'},
#  'Russell Wilson, SEA': {'name': 'Russell Wilson, SEA',
#   'position': 'QB',
#   'fpros_pre_draft$': '7',
#   'espn_pre_draft$': '2'},
#  'Tom Brady, NE': {'name': 'Tom Brady, NE',
#   'position': 'QB',
#   'fpros_pre_draft$': '7',
#   'espn_pre_draft$': '2'},
#  'Kirk Cousins, MIN': {'name': 'Kirk Cousins, MIN',
#   'position': 'QB',
#   'fpros_pre_draft$': '6',
#   'espn_pre_draft$': '0'},
#  'Mitch Trubisky, CHI': {'name': 'Mitch Trubisky, CHI',
#   'position': 'QB',
#   'fpros_pre_draft$': '6',
#   'espn_pre_draft$': '0'},
#  'Philip Rivers, LAC': {'name': 'Philip Rivers, LAC',
#   'position': 'QB',
#   'fpros_pre_draft$': '5',
#   'espn_pre_draft$': '0'},
#  'Kyler Murray, ARI': {'name': 'Kyler Murray, ARI',
#   'position': 'QB',
#   'fpros_pre_draft$': '4',
#   'espn_pre_draft$': '2'},
#  'Josh Allen, BUF': {'name': 'Josh Allen, BUF',
#   'position': 'QB',
#   'fpros_pre_draft$': '2',
#   'espn_pre_draft$': '0'},
#  'Jimmy Garoppolo, SF': {'name': 'Jimmy Garoppolo, SF',
#   'position': 'QB',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': '0'},
#  'Derek Carr, OAK': {'name': 'Derek Carr, OAK',
#   'position': 'QB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Matthew Stafford, DET': {'name': 'Matthew Stafford, DET',
#   'position': 'QB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Andy Dalton, CIN': {'name': 'Andy Dalton, CIN',
#   'position': 'QB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Sam Darnold, NYJ': {'name': 'Sam Darnold, NYJ',
#   'position': 'QB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Marcus Mariota, TEN': {'name': 'Marcus Mariota, TEN',
#   'position': 'QB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Nick Foles, JAC': {'name': 'Nick Foles, JAC',
#   'position': 'QB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Joe Flacco, DEN': {'name': 'Joe Flacco, DEN',
#   'position': 'QB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Eli Manning, NYG': {'name': 'Eli Manning, NYG',
#   'position': 'QB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Ryan Fitzpatrick, MIA': {'name': 'Ryan Fitzpatrick, MIA',
#   'position': 'QB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Dwayne Haskins, WAS': {'name': 'Dwayne Haskins, WAS',
#   'position': 'QB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Chicago Bears': {'name': 'Chicago Bears',
#   'position': 'DST',
#   'fpros_pre_draft$': '2',
#   'espn_pre_draft$': None},
#  'Los Angeles Rams': {'name': 'Los Angeles Rams',
#   'position': 'DST',
#   'fpros_pre_draft$': '2',
#   'espn_pre_draft$': None},
#  'New Orleans Saints': {'name': 'New Orleans Saints',
#   'position': 'DST',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': None},
#  'Baltimore Ravens': {'name': 'Baltimore Ravens',
#   'position': 'DST',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': None},
#  'Cleveland Browns': {'name': 'Cleveland Browns',
#   'position': 'DST',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': None},
#  'Minnesota Vikings': {'name': 'Minnesota Vikings',
#   'position': 'DST',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': None},
#  'Indianapolis Colts': {'name': 'Indianapolis Colts',
#   'position': 'DST',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': None},
#  'Pittsburgh Steelers': {'name': 'Pittsburgh Steelers',
#   'position': 'DST',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': None},
#  'Philadelphia Eagles': {'name': 'Philadelphia Eagles',
#   'position': 'DST',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': None},
#  'Los Angeles Chargers': {'name': 'Los Angeles Chargers',
#   'position': 'DST',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': None},
#  'Buffalo Bills': {'name': 'Buffalo Bills',
#   'position': 'DST',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': None},
#  'Denver Broncos': {'name': 'Denver Broncos',
#   'position': 'DST',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': None},
#  'Houston Texans': {'name': 'Houston Texans',
#   'position': 'DST',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': None},
#  'New England Patriots': {'name': 'New England Patriots',
#   'position': 'DST',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': None},
#  'Carolina Panthers': {'name': 'Carolina Panthers',
#   'position': 'DST',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Jacksonville Jaguars': {'name': 'Jacksonville Jaguars',
#   'position': 'DST',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Kansas City Chiefs': {'name': 'Kansas City Chiefs',
#   'position': 'DST',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Arizona Cardinals': {'name': 'Arizona Cardinals',
#   'position': 'DST',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Washington Redskins': {'name': 'Washington Redskins',
#   'position': 'DST',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Seattle Seahawks': {'name': 'Seattle Seahawks',
#   'position': 'DST',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Dallas Cowboys': {'name': 'Dallas Cowboys',
#   'position': 'DST',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Green Bay Packers': {'name': 'Green Bay Packers',
#   'position': 'DST',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Tennessee Titans': {'name': 'Tennessee Titans',
#   'position': 'DST',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'New York Jets': {'name': 'New York Jets',
#   'position': 'DST',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Atlanta Falcons': {'name': 'Atlanta Falcons',
#   'position': 'DST',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'San Francisco 49ers': {'name': 'San Francisco 49ers',
#   'position': 'DST',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Detroit Lions': {'name': 'Detroit Lions',
#   'position': 'DST',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Cincinnati Bengals': {'name': 'Cincinnati Bengals',
#   'position': 'DST',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'New York Giants': {'name': 'New York Giants',
#   'position': 'DST',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Tampa Bay Buccaneers': {'name': 'Tampa Bay Buccaneers',
#   'position': 'DST',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Miami Dolphins': {'name': 'Miami Dolphins',
#   'position': 'DST',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Oakland Raiders': {'name': 'Oakland Raiders',
#   'position': 'DST',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Saquon Barkley, NYG': {'name': 'Saquon Barkley, NYG',
#   'position': 'RB',
#   'fpros_pre_draft$': '64',
#   'espn_pre_draft$': '57'},
#  'Christian McCaffrey, CAR': {'name': 'Christian McCaffrey, CAR',
#   'position': 'RB',
#   'fpros_pre_draft$': '58',
#   'espn_pre_draft$': '55'},
#  'Alvin Kamara, NO': {'name': 'Alvin Kamara, NO',
#   'position': 'RB',
#   'fpros_pre_draft$': '57',
#   'espn_pre_draft$': '55'},
#  'Ezekiel Elliott, DAL': {'name': 'Ezekiel Elliott, DAL',
#   'position': 'RB',
#   'fpros_pre_draft$': '54',
#   'espn_pre_draft$': '54'},
#  "Le'Veon Bell, NYJ": {'name': "Le'Veon Bell, NYJ",
#   'position': 'RB',
#   'fpros_pre_draft$': '45',
#   'espn_pre_draft$': '51'},
#  'David Johnson, ARI': {'name': 'David Johnson, ARI',
#   'position': 'RB',
#   'fpros_pre_draft$': '44',
#   'espn_pre_draft$': '53'},
#  'James Conner, PIT': {'name': 'James Conner, PIT',
#   'position': 'RB',
#   'fpros_pre_draft$': '44',
#   'espn_pre_draft$': '37'},
#  'Todd Gurley, LAR': {'name': 'Todd Gurley, LAR',
#   'position': 'RB',
#   'fpros_pre_draft$': '42',
#   'espn_pre_draft$': '41'},
#  'Joe Mixon, CIN': {'name': 'Joe Mixon, CIN',
#   'position': 'RB',
#   'fpros_pre_draft$': '41',
#   'espn_pre_draft$': '38'},
#  'Nick Chubb, CLE': {'name': 'Nick Chubb, CLE',
#   'position': 'RB',
#   'fpros_pre_draft$': '40',
#   'espn_pre_draft$': '34'},
#  'Dalvin Cook, MIN': {'name': 'Dalvin Cook, MIN',
#   'position': 'RB',
#   'fpros_pre_draft$': '39',
#   'espn_pre_draft$': '37'},
#  'Damien Williams, KC': {'name': 'Damien Williams, KC',
#   'position': 'RB',
#   'fpros_pre_draft$': '35',
#   'espn_pre_draft$': '10'},
#  'Melvin Gordon, LAC': {'name': 'Melvin Gordon, LAC',
#   'position': 'RB',
#   'fpros_pre_draft$': '34',
#   'espn_pre_draft$': '27'},
#  'Derrick Henry, TEN': {'name': 'Derrick Henry, TEN',
#   'position': 'RB',
#   'fpros_pre_draft$': '34',
#   'espn_pre_draft$': '31'},
#  'Kerryon Johnson, DET': {'name': 'Kerryon Johnson, DET',
#   'position': 'RB',
#   'fpros_pre_draft$': '34',
#   'espn_pre_draft$': '33'},
#  'Chris Carson, SEA': {'name': 'Chris Carson, SEA',
#   'position': 'RB',
#   'fpros_pre_draft$': '34',
#   'espn_pre_draft$': '26'},
#  'Leonard Fournette, JAC': {'name': 'Leonard Fournette, JAC',
#   'position': 'RB',
#   'fpros_pre_draft$': '33',
#   'espn_pre_draft$': '32'},
#  'Marlon Mack, IND': {'name': 'Marlon Mack, IND',
#   'position': 'RB',
#   'fpros_pre_draft$': '32',
#   'espn_pre_draft$': '17'},
#  'Aaron Jones, GB': {'name': 'Aaron Jones, GB',
#   'position': 'RB',
#   'fpros_pre_draft$': '30',
#   'espn_pre_draft$': '25'},
#  'Devonta Freeman, ATL': {'name': 'Devonta Freeman, ATL',
#   'position': 'RB',
#   'fpros_pre_draft$': '29',
#   'espn_pre_draft$': '32'},
#  'Josh Jacobs, OAK': {'name': 'Josh Jacobs, OAK',
#   'position': 'RB',
#   'fpros_pre_draft$': '28',
#   'espn_pre_draft$': '26'},
#  'Sony Michel, NE': {'name': 'Sony Michel, NE',
#   'position': 'RB',
#   'fpros_pre_draft$': '28',
#   'espn_pre_draft$': '24'},
#  'David Montgomery, CHI': {'name': 'David Montgomery, CHI',
#   'position': 'RB',
#   'fpros_pre_draft$': '24',
#   'espn_pre_draft$': '10'},
#  'Mark Ingram, BAL': {'name': 'Mark Ingram, BAL',
#   'position': 'RB',
#   'fpros_pre_draft$': '24',
#   'espn_pre_draft$': '17'},
#  'Phillip Lindsay, DEN': {'name': 'Phillip Lindsay, DEN',
#   'position': 'RB',
#   'fpros_pre_draft$': '22',
#   'espn_pre_draft$': '9'},
#  'Lamar Miller, HOU': {'name': 'Lamar Miller, HOU',
#   'position': 'RB',
#   'fpros_pre_draft$': '21',
#   'espn_pre_draft$': '8'},
#  'Kenyan Drake, MIA': {'name': 'Kenyan Drake, MIA',
#   'position': 'RB',
#   'fpros_pre_draft$': '19',
#   'espn_pre_draft$': '9'},
#  'Tevin Coleman, SF': {'name': 'Tevin Coleman, SF',
#   'position': 'RB',
#   'fpros_pre_draft$': '16',
#   'espn_pre_draft$': '4'},
#  'James White, NE': {'name': 'James White, NE',
#   'position': 'RB',
#   'fpros_pre_draft$': '15',
#   'espn_pre_draft$': '9'},
#  'Derrius Guice, WAS': {'name': 'Derrius Guice, WAS',
#   'position': 'RB',
#   'fpros_pre_draft$': '13',
#   'espn_pre_draft$': '8'},
#  'Miles Sanders, PHI': {'name': 'Miles Sanders, PHI',
#   'position': 'RB',
#   'fpros_pre_draft$': '12',
#   'espn_pre_draft$': '4'},
#  'Austin Ekeler, LAC': {'name': 'Austin Ekeler, LAC',
#   'position': 'RB',
#   'fpros_pre_draft$': '12',
#   'espn_pre_draft$': '4'},
#  'Peyton Barber, TB': {'name': 'Peyton Barber, TB',
#   'position': 'RB',
#   'fpros_pre_draft$': '12',
#   'espn_pre_draft$': '2'},
#  'Tarik Cohen, CHI': {'name': 'Tarik Cohen, CHI',
#   'position': 'RB',
#   'fpros_pre_draft$': '10',
#   'espn_pre_draft$': '8'},
#  'Latavius Murray, NO': {'name': 'Latavius Murray, NO',
#   'position': 'RB',
#   'fpros_pre_draft$': '10',
#   'espn_pre_draft$': '4'},
#  'LeSean McCoy, BUF': {'name': 'LeSean McCoy, BUF',
#   'position': 'RB',
#   'fpros_pre_draft$': '9',
#   'espn_pre_draft$': '2'},
#  'Rashaad Penny, SEA': {'name': 'Rashaad Penny, SEA',
#   'position': 'RB',
#   'fpros_pre_draft$': '9',
#   'espn_pre_draft$': '4'},
#  'Jordan Howard, PHI': {'name': 'Jordan Howard, PHI',
#   'position': 'RB',
#   'fpros_pre_draft$': '9',
#   'espn_pre_draft$': '4'},
#  'Royce Freeman, DEN': {'name': 'Royce Freeman, DEN',
#   'position': 'RB',
#   'fpros_pre_draft$': '7',
#   'espn_pre_draft$': '4'},
#  'Darrell Henderson, LAR': {'name': 'Darrell Henderson, LAR',
#   'position': 'RB',
#   'fpros_pre_draft$': '7',
#   'espn_pre_draft$': '2'},
#  'Kalen Ballage, MIA': {'name': 'Kalen Ballage, MIA',
#   'position': 'RB',
#   'fpros_pre_draft$': '6',
#   'espn_pre_draft$': '1'},
#  'Matt Breida, SF': {'name': 'Matt Breida, SF',
#   'position': 'RB',
#   'fpros_pre_draft$': '6',
#   'espn_pre_draft$': '2'},
#  'Duke Johnson, HOU': {'name': 'Duke Johnson, HOU',
#   'position': 'RB',
#   'fpros_pre_draft$': '6',
#   'espn_pre_draft$': '2'},
#  'Dion Lewis, TEN': {'name': 'Dion Lewis, TEN',
#   'position': 'RB',
#   'fpros_pre_draft$': '5',
#   'espn_pre_draft$': '0'},
#  'Adrian Peterson, WAS': {'name': 'Adrian Peterson, WAS',
#   'position': 'RB',
#   'fpros_pre_draft$': '5',
#   'espn_pre_draft$': '0'},
#  'Ronald Jones II, TB': {'name': 'Ronald Jones II, TB',
#   'position': 'RB',
#   'fpros_pre_draft$': '5',
#   'espn_pre_draft$': '2'},
#  'Jaylen Samuels, PIT': {'name': 'Jaylen Samuels, PIT',
#   'position': 'RB',
#   'fpros_pre_draft$': '5',
#   'espn_pre_draft$': '1'},
#  'C.J. Anderson, DET': {'name': 'C.J. Anderson, DET',
#   'position': 'RB',
#   'fpros_pre_draft$': '4',
#   'espn_pre_draft$': '0'},
#  'Nyheim Hines, IND': {'name': 'Nyheim Hines, IND',
#   'position': 'RB',
#   'fpros_pre_draft$': '4',
#   'espn_pre_draft$': '1'},
#  'Jamaal Williams, GB': {'name': 'Jamaal Williams, GB',
#   'position': 'RB',
#   'fpros_pre_draft$': '4',
#   'espn_pre_draft$': '0'},
#  'Ito Smith, ATL': {'name': 'Ito Smith, ATL',
#   'position': 'RB',
#   'fpros_pre_draft$': '4',
#   'espn_pre_draft$': '0'},
#  'Chris Thompson, WAS': {'name': 'Chris Thompson, WAS',
#   'position': 'RB',
#   'fpros_pre_draft$': '3',
#   'espn_pre_draft$': '0'},
#  'Jalen Richard, OAK': {'name': 'Jalen Richard, OAK',
#   'position': 'RB',
#   'fpros_pre_draft$': '3',
#   'espn_pre_draft$': '0'},
#  'Kareem Hunt, CLE': {'name': 'Kareem Hunt, CLE',
#   'position': 'RB',
#   'fpros_pre_draft$': '3',
#   'espn_pre_draft$': '0'},
#  'Giovani Bernard, CIN': {'name': 'Giovani Bernard, CIN',
#   'position': 'RB',
#   'fpros_pre_draft$': '3',
#   'espn_pre_draft$': '0'},
#  'Damien Harris, NE': {'name': 'Damien Harris, NE',
#   'position': 'RB',
#   'fpros_pre_draft$': '3',
#   'espn_pre_draft$': '0'},
#  'Gus Edwards, BAL': {'name': 'Gus Edwards, BAL',
#   'position': 'RB',
#   'fpros_pre_draft$': '2',
#   'espn_pre_draft$': '0'},
#  'Carlos Hyde, KC': {'name': 'Carlos Hyde, KC',
#   'position': 'RB',
#   'fpros_pre_draft$': '2',
#   'espn_pre_draft$': '2'},
#  'Devin Singletary, BUF': {'name': 'Devin Singletary, BUF',
#   'position': 'RB',
#   'fpros_pre_draft$': '2',
#   'espn_pre_draft$': '1'},
#  'Alexander Mattison, MIN': {'name': 'Alexander Mattison, MIN',
#   'position': 'RB',
#   'fpros_pre_draft$': '2',
#   'espn_pre_draft$': '0'},
#  'Jerick McKinnon, SF': {'name': 'Jerick McKinnon, SF',
#   'position': 'RB',
#   'fpros_pre_draft$': '2',
#   'espn_pre_draft$': '0'},
#  'Frank Gore, BUF': {'name': 'Frank Gore, BUF',
#   'position': 'RB',
#   'fpros_pre_draft$': '2',
#   'espn_pre_draft$': '0'},
#  'Justice Hill, BAL': {'name': 'Justice Hill, BAL',
#   'position': 'RB',
#   'fpros_pre_draft$': '2',
#   'espn_pre_draft$': '0'},
#  'Justin Jackson, LAC': {'name': 'Justin Jackson, LAC',
#   'position': 'RB',
#   'fpros_pre_draft$': '2',
#   'espn_pre_draft$': '0'},
#  'Rodney Anderson, CIN': {'name': 'Rodney Anderson, CIN',
#   'position': 'RB',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': None},
#  'Mike Davis, CHI': {'name': 'Mike Davis, CHI',
#   'position': 'RB',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': '0'},
#  'Alfred Blue, JAC': {'name': 'Alfred Blue, JAC',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Darwin Thompson, KC': {'name': 'Darwin Thompson, KC',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Tony Pollard, DAL': {'name': 'Tony Pollard, DAL',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Bilal Powell, NYJ': {'name': 'Bilal Powell, NYJ',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Doug Martin, OAK': {'name': 'Doug Martin, OAK',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Chase Edmonds, ARI': {'name': 'Chase Edmonds, ARI',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Rex Burkhead, NE': {'name': 'Rex Burkhead, NE',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Ty Montgomery, NYJ': {'name': 'Ty Montgomery, NYJ',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Zach Zenner, DET': {'name': 'Zach Zenner, DET',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Corey Clement, PHI': {'name': 'Corey Clement, PHI',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Dontrell Hilliard, CLE': {'name': 'Dontrell Hilliard, CLE',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Ty Johnson, DET': {'name': 'Ty Johnson, DET',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Theo Riddick, DEN': {'name': 'Theo Riddick, DEN',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'T.J. Yeldon, BUF': {'name': 'T.J. Yeldon, BUF',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Elijah McGuire, NYJ': {'name': 'Elijah McGuire, NYJ',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Wayne Gallman, NYG': {'name': 'Wayne Gallman, NYG',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Ryquell Armstead, JAC': {'name': 'Ryquell Armstead, JAC',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Malcolm Brown, LAR': {'name': 'Malcolm Brown, LAR',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Cameron Artis-Payne, CAR': {'name': 'Cameron Artis-Payne, CAR',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Brandon Bolden, NE': {'name': 'Brandon Bolden, NE',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Brian Hill, ATL': {'name': 'Brian Hill, ATL',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'J.D. McKissic, SEA': {'name': 'J.D. McKissic, SEA',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Reggie Bonnafon, CAR': {'name': 'Reggie Bonnafon, CAR',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Dexter Williams, GB': {'name': 'Dexter Williams, GB',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Kyle Juszczyk, SF': {'name': 'Kyle Juszczyk, SF',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Jordan Wilkins, IND': {'name': 'Jordan Wilkins, IND',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Andre Ellington, TB': {'name': 'Andre Ellington, TB',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Devontae Booker, DEN': {'name': 'Devontae Booker, DEN',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Josh Ferguson, HOU': {'name': 'Josh Ferguson, HOU',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Darren Sproles, PHI': {'name': 'Darren Sproles, PHI',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Damarea Crockett, HOU': {'name': 'Damarea Crockett, HOU',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Kenneth Dixon, BAL': {'name': 'Kenneth Dixon, BAL',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Myles Gaskin, MIA': {'name': 'Myles Gaskin, MIA',
#   'position': 'RB',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'DeAndre Hopkins, HOU': {'name': 'DeAndre Hopkins, HOU',
#   'position': 'WR',
#   'fpros_pre_draft$': '48',
#   'espn_pre_draft$': '50'},
#  'Julio Jones, ATL': {'name': 'Julio Jones, ATL',
#   'position': 'WR',
#   'fpros_pre_draft$': '48',
#   'espn_pre_draft$': '45'},
#  'Tyreek Hill, KC': {'name': 'Tyreek Hill, KC',
#   'position': 'WR',
#   'fpros_pre_draft$': '46',
#   'espn_pre_draft$': '45'},
#  'Davante Adams, GB': {'name': 'Davante Adams, GB',
#   'position': 'WR',
#   'fpros_pre_draft$': '45',
#   'espn_pre_draft$': '47'},
#  'JuJu Smith-Schuster, PIT': {'name': 'JuJu Smith-Schuster, PIT',
#   'position': 'WR',
#   'fpros_pre_draft$': '43',
#   'espn_pre_draft$': '43'},
#  'Michael Thomas, NO': {'name': 'Michael Thomas, NO',
#   'position': 'WR',
#   'fpros_pre_draft$': '40',
#   'espn_pre_draft$': '50'},
#  'Mike Evans, TB': {'name': 'Mike Evans, TB',
#   'position': 'WR',
#   'fpros_pre_draft$': '39',
#   'espn_pre_draft$': '39'},
#  'Odell Beckham Jr., CLE': {'name': 'Odell Beckham Jr., CLE',
#   'position': 'WR',
#   'fpros_pre_draft$': '38',
#   'espn_pre_draft$': '47'},
#  'Antonio Brown, OAK': {'name': 'Antonio Brown, OAK',
#   'position': 'WR',
#   'fpros_pre_draft$': '36',
#   'espn_pre_draft$': '36'},
#  'Keenan Allen, LAC': {'name': 'Keenan Allen, LAC',
#   'position': 'WR',
#   'fpros_pre_draft$': '34',
#   'espn_pre_draft$': '30'},
#  'T.Y. Hilton, IND': {'name': 'T.Y. Hilton, IND',
#   'position': 'WR',
#   'fpros_pre_draft$': '32',
#   'espn_pre_draft$': '30'},
#  'Adam Thielen, MIN': {'name': 'Adam Thielen, MIN',
#   'position': 'WR',
#   'fpros_pre_draft$': '30',
#   'espn_pre_draft$': '22'},
#  'Brandin Cooks, LAR': {'name': 'Brandin Cooks, LAR',
#   'position': 'WR',
#   'fpros_pre_draft$': '29',
#   'espn_pre_draft$': '23'},
#  'Julian Edelman, NE': {'name': 'Julian Edelman, NE',
#   'position': 'WR',
#   'fpros_pre_draft$': '29',
#   'espn_pre_draft$': '21'},
#  'Amari Cooper, DAL': {'name': 'Amari Cooper, DAL',
#   'position': 'WR',
#   'fpros_pre_draft$': '28',
#   'espn_pre_draft$': '36'},
#  'Robert Woods, LAR': {'name': 'Robert Woods, LAR',
#   'position': 'WR',
#   'fpros_pre_draft$': '27',
#   'espn_pre_draft$': '21'},
#  'Stefon Diggs, MIN': {'name': 'Stefon Diggs, MIN',
#   'position': 'WR',
#   'fpros_pre_draft$': '27',
#   'espn_pre_draft$': '20'},
#  'Tyler Lockett, SEA': {'name': 'Tyler Lockett, SEA',
#   'position': 'WR',
#   'fpros_pre_draft$': '26',
#   'espn_pre_draft$': '15'},
#  'Kenny Golladay, DET': {'name': 'Kenny Golladay, DET',
#   'position': 'WR',
#   'fpros_pre_draft$': '24',
#   'espn_pre_draft$': '20'},
#  'Cooper Kupp, LAR': {'name': 'Cooper Kupp, LAR',
#   'position': 'WR',
#   'fpros_pre_draft$': '22',
#   'espn_pre_draft$': '13'},
#  'Chris Godwin, TB': {'name': 'Chris Godwin, TB',
#   'position': 'WR',
#   'fpros_pre_draft$': '21',
#   'espn_pre_draft$': '16'},
#  'Mike Williams, LAC': {'name': 'Mike Williams, LAC',
#   'position': 'WR',
#   'fpros_pre_draft$': '20',
#   'espn_pre_draft$': '14'},
#  'Tyler Boyd, CIN': {'name': 'Tyler Boyd, CIN',
#   'position': 'WR',
#   'fpros_pre_draft$': '20',
#   'espn_pre_draft$': '10'},
#  'Alshon Jeffery, PHI': {'name': 'Alshon Jeffery, PHI',
#   'position': 'WR',
#   'fpros_pre_draft$': '18',
#   'espn_pre_draft$': '19'},
#  'A.J. Green, CIN': {'name': 'A.J. Green, CIN',
#   'position': 'WR',
#   'fpros_pre_draft$': '18',
#   'espn_pre_draft$': '10'},
#  'Allen Robinson, CHI': {'name': 'Allen Robinson, CHI',
#   'position': 'WR',
#   'fpros_pre_draft$': '16',
#   'espn_pre_draft$': '12'},
#  'D.J. Moore, CAR': {'name': 'D.J. Moore, CAR',
#   'position': 'WR',
#   'fpros_pre_draft$': '16',
#   'espn_pre_draft$': '12'},
#  'Sammy Watkins, KC': {'name': 'Sammy Watkins, KC',
#   'position': 'WR',
#   'fpros_pre_draft$': '16',
#   'espn_pre_draft$': '11'},
#  'Calvin Ridley, ATL': {'name': 'Calvin Ridley, ATL',
#   'position': 'WR',
#   'fpros_pre_draft$': '16',
#   'espn_pre_draft$': '11'},
#  'Robby Anderson, NYJ': {'name': 'Robby Anderson, NYJ',
#   'position': 'WR',
#   'fpros_pre_draft$': '14',
#   'espn_pre_draft$': '6'},
#  'Josh Gordon, NE': {'name': 'Josh Gordon, NE',
#   'position': 'WR',
#   'fpros_pre_draft$': '14',
#   'espn_pre_draft$': '3'},
#  'Jarvis Landry, CLE': {'name': 'Jarvis Landry, CLE',
#   'position': 'WR',
#   'fpros_pre_draft$': '14',
#   'espn_pre_draft$': '6'},
#  'Marvin Jones, DET': {'name': 'Marvin Jones, DET',
#   'position': 'WR',
#   'fpros_pre_draft$': '13',
#   'espn_pre_draft$': '5'},
#  'Christian Kirk, ARI': {'name': 'Christian Kirk, ARI',
#   'position': 'WR',
#   'fpros_pre_draft$': '12',
#   'espn_pre_draft$': '5'},
#  'Dante Pettis, SF': {'name': 'Dante Pettis, SF',
#   'position': 'WR',
#   'fpros_pre_draft$': '12',
#   'espn_pre_draft$': '2'},
#  'Sterling Shepard, NYG': {'name': 'Sterling Shepard, NYG',
#   'position': 'WR',
#   'fpros_pre_draft$': '11',
#   'espn_pre_draft$': '6'},
#  'Will Fuller, HOU': {'name': 'Will Fuller, HOU',
#   'position': 'WR',
#   'fpros_pre_draft$': '11',
#   'espn_pre_draft$': '3'},
#  'Curtis Samuel, CAR': {'name': 'Curtis Samuel, CAR',
#   'position': 'WR',
#   'fpros_pre_draft$': '11',
#   'espn_pre_draft$': '5'},
#  'Dede Westbrook, JAC': {'name': 'Dede Westbrook, JAC',
#   'position': 'WR',
#   'fpros_pre_draft$': '10',
#   'espn_pre_draft$': '5'},
#  'Emmanuel Sanders, DEN': {'name': 'Emmanuel Sanders, DEN',
#   'position': 'WR',
#   'fpros_pre_draft$': '10',
#   'espn_pre_draft$': '4'},
#  'Corey Davis, TEN': {'name': 'Corey Davis, TEN',
#   'position': 'WR',
#   'fpros_pre_draft$': '10',
#   'espn_pre_draft$': '3'},
#  'Larry Fitzgerald, ARI': {'name': 'Larry Fitzgerald, ARI',
#   'position': 'WR',
#   'fpros_pre_draft$': '8',
#   'espn_pre_draft$': '2'},
#  'Kenny Stills, MIA': {'name': 'Kenny Stills, MIA',
#   'position': 'WR',
#   'fpros_pre_draft$': '7',
#   'espn_pre_draft$': '2'},
#  'Courtland Sutton, DEN': {'name': 'Courtland Sutton, DEN',
#   'position': 'WR',
#   'fpros_pre_draft$': '7',
#   'espn_pre_draft$': '3'},
#  'DeSean Jackson, PHI': {'name': 'DeSean Jackson, PHI',
#   'position': 'WR',
#   'fpros_pre_draft$': '7',
#   'espn_pre_draft$': '2'},
#  'Mohamed Sanu, ATL': {'name': 'Mohamed Sanu, ATL',
#   'position': 'WR',
#   'fpros_pre_draft$': '6',
#   'espn_pre_draft$': '1'},
#  'Michael Gallup, DAL': {'name': 'Michael Gallup, DAL',
#   'position': 'WR',
#   'fpros_pre_draft$': '6',
#   'espn_pre_draft$': '3'},
#  'Donte Moncrief, PIT': {'name': 'Donte Moncrief, PIT',
#   'position': 'WR',
#   'fpros_pre_draft$': '6',
#   'espn_pre_draft$': '2'},
#  'Jamison Crowder, NYJ': {'name': 'Jamison Crowder, NYJ',
#   'position': 'WR',
#   'fpros_pre_draft$': '5',
#   'espn_pre_draft$': '3'},
#  'Tyrell Williams, OAK': {'name': 'Tyrell Williams, OAK',
#   'position': 'WR',
#   'fpros_pre_draft$': '5',
#   'espn_pre_draft$': '2'},
#  'Geronimo Allison, GB': {'name': 'Geronimo Allison, GB',
#   'position': 'WR',
#   'fpros_pre_draft$': '5',
#   'espn_pre_draft$': '2'},
#  'Ted Ginn, NO': {'name': 'Ted Ginn, NO',
#   'position': 'WR',
#   'fpros_pre_draft$': '5',
#   'espn_pre_draft$': '0'},
#  'John Brown, BUF': {'name': 'John Brown, BUF',
#   'position': 'WR',
#   'fpros_pre_draft$': '4',
#   'espn_pre_draft$': '2'},
#  'Marquez Valdes-Scantling, GB': {'name': 'Marquez Valdes-Scantling, GB',
#   'position': 'WR',
#   'fpros_pre_draft$': '4',
#   'espn_pre_draft$': '2'},
#  'Devin Funchess, IND': {'name': 'Devin Funchess, IND',
#   'position': 'WR',
#   'fpros_pre_draft$': '4',
#   'espn_pre_draft$': '2'},
#  'Anthony Miller, CHI': {'name': 'Anthony Miller, CHI',
#   'position': 'WR',
#   'fpros_pre_draft$': '3',
#   'espn_pre_draft$': '2'},
#  'Albert Wilson, MIA': {'name': 'Albert Wilson, MIA',
#   'position': 'WR',
#   'fpros_pre_draft$': '3',
#   'espn_pre_draft$': '0'},
#  'DaeSean Hamilton, DEN': {'name': 'DaeSean Hamilton, DEN',
#   'position': 'WR',
#   'fpros_pre_draft$': '3',
#   'espn_pre_draft$': '2'},
#  'Devante Parker, MIA': {'name': 'Devante Parker, MIA',
#   'position': 'WR',
#   'fpros_pre_draft$': '2',
#   'espn_pre_draft$': None},
#  'James Washington, PIT': {'name': 'James Washington, PIT',
#   'position': 'WR',
#   'fpros_pre_draft$': '2',
#   'espn_pre_draft$': '2'},
#  'Keke Coutee, HOU': {'name': 'Keke Coutee, HOU',
#   'position': 'WR',
#   'fpros_pre_draft$': '2',
#   'espn_pre_draft$': '2'},
#  'D.K. Metcalf, SEA': {'name': 'D.K. Metcalf, SEA',
#   'position': 'WR',
#   'fpros_pre_draft$': '2',
#   'espn_pre_draft$': None},
#  'Golden Tate, NYG': {'name': 'Golden Tate, NYG',
#   'position': 'WR',
#   'fpros_pre_draft$': '2',
#   'espn_pre_draft$': '0'},
#  'Marquise Goodwin, SF': {'name': 'Marquise Goodwin, SF',
#   'position': 'WR',
#   'fpros_pre_draft$': '2',
#   'espn_pre_draft$': None},
#  'Adam Humphries, TEN': {'name': 'Adam Humphries, TEN',
#   'position': 'WR',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': '2'},
#  'Marqise Lee, JAC': {'name': 'Marqise Lee, JAC',
#   'position': 'WR',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': None},
#  'Paul Richardson, WAS': {'name': 'Paul Richardson, WAS',
#   'position': 'WR',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': '0'},
#  'Zay Jones, BUF': {'name': 'Zay Jones, BUF',
#   'position': 'WR',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': '0'},
#  'Marquise Brown, BAL': {'name': 'Marquise Brown, BAL',
#   'position': 'WR',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': '0'},
#  'Robert Foster, BUF': {'name': 'Robert Foster, BUF',
#   'position': 'WR',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': '0'},
#  'Deebo Samuel, SF': {'name': 'Deebo Samuel, SF',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Taylor Gabriel, CHI': {'name': 'Taylor Gabriel, CHI',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Quincy Enunwa, NYJ': {'name': 'Quincy Enunwa, NYJ',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Parris Campbell, IND': {'name': 'Parris Campbell, IND',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '1'},
#  'Josh Doctson, WAS': {'name': 'Josh Doctson, WAS',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Danny Amendola, DET': {'name': 'Danny Amendola, DET',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  "Tre'Quan Smith, NO": {'name': "Tre'Quan Smith, NO",
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'David Moore, SEA': {'name': 'David Moore, SEA',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Cole Beasley, BUF': {'name': 'Cole Beasley, BUF',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Willie Snead, BAL': {'name': 'Willie Snead, BAL',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Randall Cobb, DAL': {'name': 'Randall Cobb, DAL',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Rashard Higgins, CLE': {'name': 'Rashard Higgins, CLE',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Nelson Agholor, PHI': {'name': 'Nelson Agholor, PHI',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Breshad Perriman, TB': {'name': 'Breshad Perriman, TB',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  "N'Keal Harry, NE": {'name': "N'Keal Harry, NE",
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Chris Conley, JAC': {'name': 'Chris Conley, JAC',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Miles Boykin, BAL': {'name': 'Miles Boykin, BAL',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'John Ross, CIN': {'name': 'John Ross, CIN',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'A.J. Brown, TEN': {'name': 'A.J. Brown, TEN',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Andy Isabella, ARI': {'name': 'Andy Isabella, ARI',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Mecole Hardman, KC': {'name': 'Mecole Hardman, KC',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Terry McLaurin, WAS': {'name': 'Terry McLaurin, WAS',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Travis Benjamin, LAC': {'name': 'Travis Benjamin, LAC',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Trey Quinn, WAS': {'name': 'Trey Quinn, WAS',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Cody Latimer, NYG': {'name': 'Cody Latimer, NYG',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'D.J. Chark, JAC': {'name': 'D.J. Chark, JAC',
#   'position': 'WR',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Travis Kelce, KC': {'name': 'Travis Kelce, KC',
#   'position': 'TE',
#   'fpros_pre_draft$': '39',
#   'espn_pre_draft$': '39'},
#  'George Kittle, SF': {'name': 'George Kittle, SF',
#   'position': 'TE',
#   'fpros_pre_draft$': '30',
#   'espn_pre_draft$': '28'},
#  'Zach Ertz, PHI': {'name': 'Zach Ertz, PHI',
#   'position': 'TE',
#   'fpros_pre_draft$': '24',
#   'espn_pre_draft$': '27'},
#  'O.J. Howard, TB': {'name': 'O.J. Howard, TB',
#   'position': 'TE',
#   'fpros_pre_draft$': '17',
#   'espn_pre_draft$': '7'},
#  'Jared Cook, NO': {'name': 'Jared Cook, NO',
#   'position': 'TE',
#   'fpros_pre_draft$': '15',
#   'espn_pre_draft$': '7'},
#  'Evan Engram, NYG': {'name': 'Evan Engram, NYG',
#   'position': 'TE',
#   'fpros_pre_draft$': '14',
#   'espn_pre_draft$': '7'},
#  'Hunter Henry, LAC': {'name': 'Hunter Henry, LAC',
#   'position': 'TE',
#   'fpros_pre_draft$': '12',
#   'espn_pre_draft$': '7'},
#  'Vance McDonald, PIT': {'name': 'Vance McDonald, PIT',
#   'position': 'TE',
#   'fpros_pre_draft$': '9',
#   'espn_pre_draft$': '2'},
#  'Eric Ebron, IND': {'name': 'Eric Ebron, IND',
#   'position': 'TE',
#   'fpros_pre_draft$': '8',
#   'espn_pre_draft$': '2'},
#  'David Njoku, CLE': {'name': 'David Njoku, CLE',
#   'position': 'TE',
#   'fpros_pre_draft$': '7',
#   'espn_pre_draft$': '2'},
#  'Delanie Walker, TEN': {'name': 'Delanie Walker, TEN',
#   'position': 'TE',
#   'fpros_pre_draft$': '5',
#   'espn_pre_draft$': '2'},
#  'Jordan Reed, WAS': {'name': 'Jordan Reed, WAS',
#   'position': 'TE',
#   'fpros_pre_draft$': '5',
#   'espn_pre_draft$': '1'},
#  'Mark Andrews, BAL': {'name': 'Mark Andrews, BAL',
#   'position': 'TE',
#   'fpros_pre_draft$': '5',
#   'espn_pre_draft$': '1'},
#  'Austin Hooper, ATL': {'name': 'Austin Hooper, ATL',
#   'position': 'TE',
#   'fpros_pre_draft$': '5',
#   'espn_pre_draft$': '1'},
#  'Jimmy Graham, GB': {'name': 'Jimmy Graham, GB',
#   'position': 'TE',
#   'fpros_pre_draft$': '3',
#   'espn_pre_draft$': '0'},
#  'Greg Olsen, CAR': {'name': 'Greg Olsen, CAR',
#   'position': 'TE',
#   'fpros_pre_draft$': '3',
#   'espn_pre_draft$': '0'},
#  'Trey Burton, CHI': {'name': 'Trey Burton, CHI',
#   'position': 'TE',
#   'fpros_pre_draft$': '3',
#   'espn_pre_draft$': '1'},
#  'Kyle Rudolph, MIN': {'name': 'Kyle Rudolph, MIN',
#   'position': 'TE',
#   'fpros_pre_draft$': '3',
#   'espn_pre_draft$': '0'},
#  'Jack Doyle, IND': {'name': 'Jack Doyle, IND',
#   'position': 'TE',
#   'fpros_pre_draft$': '2',
#   'espn_pre_draft$': '0'},
#  'Noah Fant, DEN': {'name': 'Noah Fant, DEN',
#   'position': 'TE',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': '0'},
#  'T.J. Hockenson, DET': {'name': 'T.J. Hockenson, DET',
#   'position': 'TE',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': '0'},
#  'Tyler Eifert, CIN': {'name': 'Tyler Eifert, CIN',
#   'position': 'TE',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': '0'},
#  'Jason Witten, DAL': {'name': 'Jason Witten, DAL',
#   'position': 'TE',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Chris Herndon IV, NYJ': {'name': 'Chris Herndon IV, NYJ',
#   'position': 'TE',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Dallas Goedert, PHI': {'name': 'Dallas Goedert, PHI',
#   'position': 'TE',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Darren Waller, OAK': {'name': 'Darren Waller, OAK',
#   'position': 'TE',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Will Dissly, SEA': {'name': 'Will Dissly, SEA',
#   'position': 'TE',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Greg Zuerlein, LAR': {'name': 'Greg Zuerlein, LAR',
#   'position': 'K',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': '1'},
#  'Justin Tucker, BAL': {'name': 'Justin Tucker, BAL',
#   'position': 'K',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': '1'},
#  'Stephen Gostkowski, NE': {'name': 'Stephen Gostkowski, NE',
#   'position': 'K',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': '1'},
#  'Wil Lutz, NO': {'name': 'Wil Lutz, NO',
#   'position': 'K',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': '1'},
#  'Harrison Butker, KC': {'name': 'Harrison Butker, KC',
#   'position': 'K',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': '1'},
#  "Ka'imi Fairbairn, HOU": {'name': "Ka'imi Fairbairn, HOU",
#   'position': 'K',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': '1'},
#  'Robbie Gould, SF': {'name': 'Robbie Gould, SF',
#   'position': 'K',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': '1'},
#  'Michael Badgley, LAC': {'name': 'Michael Badgley, LAC',
#   'position': 'K',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': None},
#  'Matt Gay, TB': {'name': 'Matt Gay, TB',
#   'position': 'K',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': None},
#  'Adam Vinatieri, IND': {'name': 'Adam Vinatieri, IND',
#   'position': 'K',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': '1'},
#  'Jake Elliott, PHI': {'name': 'Jake Elliott, PHI',
#   'position': 'K',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': '1'},
#  'Brett Maher, DAL': {'name': 'Brett Maher, DAL',
#   'position': 'K',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': '1'},
#  'Mason Crosby, GB': {'name': 'Mason Crosby, GB',
#   'position': 'K',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': '0'},
#  'Giorgio Tavecchio, ATL': {'name': 'Giorgio Tavecchio, ATL',
#   'position': 'K',
#   'fpros_pre_draft$': '1',
#   'espn_pre_draft$': None},
#  'Matt Prater, DET': {'name': 'Matt Prater, DET',
#   'position': 'K',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '1'},
#  'Austin Seibert, CLE': {'name': 'Austin Seibert, CLE',
#   'position': 'K',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Ryan Succop, TEN': {'name': 'Ryan Succop, TEN',
#   'position': 'K',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': '0'},
#  'Jason Myers, SEA': {'name': 'Jason Myers, SEA',
#   'position': 'K',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None},
#  'Graham Gano, CAR': {'name': 'Graham Gano, CAR',
#   'position': 'K',
#   'fpros_pre_draft$': '0',
#   'espn_pre_draft$': None}}

# %%
 pickle.dump(all_players, open('./AuctionDraft_Tool/app/all_players.sav', 'wb'))

# %% [markdown]
# ### Have a look at any stark differences in

# %%
for key in espn_players:
    if key in fpros_players.keys() and \
    (int(espn_players[key]['pre_draft$']) > 5 or int(fpros_players[key]['pre_draft$'][1:]) > 5) and \
    abs(int(espn_players[key]['pre_draft$']) - int(fpros_players[key]['pre_draft$'][1:])) > 10:
        print('Player: ', key, ' A$: ', espn_players[key]['pre_draft$'], ' B$: ', fpros_players[key]['pre_draft$'])

# %% [markdown]
# - This is everywhere with a > $10 difference

# %% [markdown]
# ### Other notes
# - Before next nomination
#     - ~~Swap All Opponent Budgets with total $ avail as a percentage~~
#     - For each starting position:
#         - ~~How many each team has avail to START, and their max bid, and total starters missing~~
#
# - When a player is on the board
#     - ~~Include total STARTING roster spots empty for each fantasy_team when player is on the board~~
#     - ~~Show both pre-draft $, still show % of money in play~~

# %%
for player in all_players:
    if 'q' in player:
        print(player, all_players[player]['position'])
# Out:
# Saquon Barkley, NYG RB
# Ryquell Armstead, JAC RB
# Marquez Valdes-Scantling, GB WR
# Marquise Goodwin, SF WR
# Marqise Lee, JAC WR
# Marquise Brown, BAL WR

# %%
for player in all_players:
    if len(player.split(' ')[1]) > 10:
        print(player, all_players[player]['position'])
# Out:
# Ben Roethlisberger, PIT QB
# Ryan Fitzpatrick, MIA QB
# David Montgomery, CHI RB
# Devin Singletary, BUF RB
# Ty Montgomery, NYJ RB
# Cameron Artis-Payne, CAR RB
# JuJu Smith-Schuster, PIT WR
# Larry Fitzgerald, ARI WR
# Marquez Valdes-Scantling, GB WR
# James Washington, PIT WR
# Paul Richardson, WAS WR
# Stephen Gostkowski, NE K
